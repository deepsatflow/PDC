# %% [markdown]
# <a href="https://colab.research.google.com/github/deepsatflow/adaptyv-bio-pdc/blob/main/BindCraft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BindCraft: Protein binder design
#
# <img src="https://github.com/martinpacesa/BindCraft/blob/main/pipeline.png?raw=true">
#
# Simple binder design pipeline using AlphaFold2 backpropagation, MPNN, and PyRosetta. Select your target and let the script do the rest of the work and finish once you have enough designs to order!
#
# The designs will be saved on your Google Drive under BindCraft/[design_name]/ and you can continue running the design pipeline if the session times out and it will continue adding new designs.

# %%
#@title Installation
# %%time
import os, time, gc, io
import contextlib
from datetime import datetime
import json

if not os.path.isfile("bindcraft/params/done.txt"):
  print("Installing required BindCraft components")

  print("Pulling BindCraft code from Github")
  os.makedirs('/content/bindcraft/', exist_ok=True)
  # !git clone https://github.com/martinpacesa/BindCraft /content/bindcraft/
  os.system("chmod +x /content/bindcraft/functions/dssp")
  os.system("chmod +x /content/bindcraft/functions/DAlphaBall.gcc")

  print("Installing ColabDesign")
  os.system("(mkdir bindcraft/params; apt-get install aria2 -qq; \
  aria2c -q -x 16 https://storage.googleapis.com/alphafold/alphafold_params_2022-12-06.tar; \
  tar -xf alphafold_params_2022-12-06.tar -C bindcraft/params; touch bindcraft/params/done.txt )&")
  os.system("pip install git+https://github.com/sokrypton/ColabDesign.git")
  # for debugging purposes
  os.system("ln -s /usr/local/lib/python3.*/dist-packages/colabdesign colabdesign")

  print("Installing PyRosetta")
  os.system("pip install pyrosettacolabsetup")
  with contextlib.redirect_stdout(io.StringIO()):
    import pyrosettacolabsetup
    pyrosettacolabsetup.install_pyrosetta(serialization=True, cache_wheel_on_google_drive=False)

  print("Downgrading BioPython")
  os.system("pip uninstall -y biopython")
  os.system("pip install biopython==1.79")

  # download params
  if not os.path.isfile("bindcraft/params/done.txt"):
    print("downloading AlphaFold params")
    while not os.path.isfile("bindcraft/params/done.txt"):
      time.sleep(5)

  print("BindCraft installation is finished, ready to run!")
else:
  print("BindCraft components already installed, ready to run!")
# Out:
# BindCraft components already installed, ready to run!
# CPU times: user 0 ns, sys: 543 µs, total: 543 µs
# Wall time: 435 µs

# %%
#@title Mount your Google Drive to save design results
from google.colab import drive
drive.mount('/content/drive')
currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Google drive mounted at: {currenttime}")

bindcraft_google_drive = '/content/drive/My Drive/BindCraft/'
os.makedirs(bindcraft_google_drive, exist_ok=True)
print("BindCraft folder successfully created in your drive!")
# Out:
# Mounted at /content/drive
# Google drive mounted at: 2024-10-04 16:17:48
# BindCraft folder successfully created in your drive!

# %%
#@title Binder design settings
# @markdown ---
# @markdown Enter path where to save your designs. We recommend to save on Google drive so that you can continue generating at any time.
design_path = "/content/drive/MyDrive/BindCraft/6ARU/" # @param {"type":"string","placeholder":"/content/drive/MyDrive/BindCraft/PDL1/"}

# @markdown Enter the name that should be prefixed to your binders (generally target name).
binder_name = "6ARU" # @param {"type":"string","placeholder":"PDL1"}

# @markdown The path to the .pdb structure of your target. Can be an experimental or AlphaFold2 structure. We recommend trimming the structure to as small as needed, as the whole selected chains will be backpropagated through the network and can significantly increase running times.
starting_pdb = "/content/6ARU_CHAIN_A_TRIMMED.pdb" # @param {"type":"string","placeholder":"/content/bindcraft/example/PDL1.pdb"}

# @markdown Which chains of your PDB to target? Can be one or multiple, in a comma-separated format. Other chains will be ignored during design.
chains = "A" # @param {"type":"string","placeholder":"A,C"}

# @markdown What positions to target in your protein of interest? For example `1,2-10` or chain specific `A1-10,B1-20` or entire chains `A`. If left blank, an appropriate site will be selected by the pipeline.
target_hotspot_residues = "" # @param {"type":"string","placeholder":""}

# @markdown What is the minimum and maximum size of binders you want to design? Pipeline will randomly sample different sizes between these values.
lengths = "48,48" # @param {"type":"string","placeholder":"70,150"}

# @markdown How many binder designs passing filters do you require?
number_of_final_designs = 5 # @param {"type":"integer","placeholder":"100"}
# @markdown ---

lengths = [int(x.strip()) for x in lengths.split(',') if len(lengths.split(',')) == 2]

if len(lengths) != 2:
    raise ValueError("Incorrect specification of binder lengths.")


settings = {
    "design_path": design_path,
    "binder_name": binder_name,
    "starting_pdb": starting_pdb,
    "chains": chains,
    "target_hotspot_residues": target_hotspot_residues,
    "lengths": lengths,
    "number_of_final_designs": number_of_final_designs
}

target_settings_path = "/content/bindcraft/settings_target/"+binder_name+".json"

with open(target_settings_path, 'w') as f:
    json.dump(settings, f, indent=4)

currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Binder design settings updated at: {currenttime}")
print(f"New .json file with target settings has been generated in: {target_settings_path}")
# Out:
# Binder design settings updated at: 2024-10-04 16:17:48
# New .json file with target settings has been generated in: /content/bindcraft/settings_target/6ARU.json

# %%
#@title Advanced settings
# @markdown ---
# @markdown Which binder design protocol to run? Default is recommended. "Beta-sheet" promotes the design of more beta sheeted proteins, but requires more sampling. "Peptide" is optimised for helical peptide binders.
advanced_option = "Default" # @param ["Default","Beta-sheet","Peptide"]
# @markdown ---

if advanced_option == "Default":
    advanced_settings_path = "/content/bindcraft/settings_advanced/4stage_multimer.json"
elif advanced_option == "Beta-sheet":
    advanced_settings_path = "/content/bindcraft/settings_advanced/4stage_multimer_beta.json"
elif advanced_option == "Peptide":
    advanced_settings_path = "/content/bindcraft/settings_advanced/4stage_multimer_peptides.json"
else:
    raise ValueError(f"Unsupported protocol")

currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Advanced design settings updated at: {currenttime}")
# Out:
# Advanced design settings updated at: 2024-10-04 16:17:48

# %%
#@title Filters
# @markdown ---
# @markdown Which filters for designs to use? "Default" are recommended, "Peptide" are for the design of peptide binders, "None" is for benchmarking.
filter_option = "Default" # @param ["Default","Peptide", "None"]
# @markdown ---

if filter_option == "Default":
    filter_settings_path = "/content/bindcraft/settings_filters/default_filters.json"
elif filter_option == "None":
    filter_settings_path = "/content/bindcraft/settings_filters/no_filters.json"
elif filter_option == "Peptide":
    filter_settings_path = "/content/bindcraft/settings_filters/filters_peptides.json"
else:
    raise ValueError(f"Unsupported filter type")

currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Filter settings updated at: {currenttime}")
# Out:
# Filter settings updated at: 2024-10-04 16:17:48

# %% [markdown]
# # Everything is set, BindCraft is ready to run!

# %%
# @title Import functions and settings
from bindcraft.functions import *

args = {"settings":target_settings_path,
        "filters":filter_settings_path,
        "advanced":advanced_settings_path}

# Check if JAX-capable GPU is available, otherwise exit
check_jax_gpu()

# perform checks of input setting files
settings_path, filters_path, advanced_path = (args["settings"], args["filters"], args["advanced"])

### load settings from JSON
target_settings, advanced_settings, filters = load_json_settings(settings_path, filters_path, advanced_path)

settings_file = os.path.basename(settings_path).split('.')[0]
filters_file = os.path.basename(filters_path).split('.')[0]
advanced_file = os.path.basename(advanced_path).split('.')[0]

### set package settings
advanced_settings["af_params_dir"] = '/content/bindcraft/params/'
advanced_settings["dssp_path"] = '/content/bindcraft/functions/dssp'
advanced_settings["dalphaball_path"] = '/content/bindcraft/functions/DAlphaBall.gcc'

### load AF2 model settings
design_models, prediction_models, multimer_validation = load_af2_models(advanced_settings["use_multimer_design"])

### generate directories, design path names can be found within the function
design_paths = generate_directories(target_settings["design_path"])

### generate dataframes
trajectory_labels, design_labels, final_labels = generate_dataframe_labels()

trajectory_csv = os.path.join(target_settings["design_path"], 'trajectory_stats.csv')
mpnn_csv = os.path.join(target_settings["design_path"], 'mpnn_design_stats.csv')
final_csv = os.path.join(target_settings["design_path"], 'final_design_stats.csv')
failure_csv = os.path.join(target_settings["design_path"], 'failure_csv.csv')

create_dataframe(trajectory_csv, trajectory_labels)
create_dataframe(mpnn_csv, design_labels)
create_dataframe(final_csv, final_labels)
generate_filter_pass_csv(failure_csv, args["filters"])

currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Loaded design functions and settings at: {currenttime}")
# Out:
# Available GPUs:
# NVIDIA A100-SXM4-40GB1: gpu
# Loaded design functions and settings at: 2024-10-04 16:17:54

# %%
#@title Initialise PyRosetta

####################################
####################################
####################################
### initialise PyRosetta
pr.init(f'-ignore_unrecognized_res -ignore_zero_occupancy -mute all -holes:dalphaball {advanced_settings["dalphaball_path"]} -corrections::beta_nov16 true -relax:default_repeats 1')
# Out:
# ┌──────────────────────────────────────────────────────────────────────────────┐
# │                                 PyRosetta-4                                  │
# │              Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │              (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                              │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRE PURCHASE OF A LICENSE │
# │         See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └──────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2024 [Rosetta PyRosetta4.Release.python310.ubuntu.cxx11thread.serialization 2024.39+release.59628fbc5bc09f1221e1642f1f8d157ce49b1410 2024-09-23T07:49:48] retrieved from: http://www.pyrosetta.org

# %%
#@title Run BindCraft!
####################################
###################### BindCraft Run
####################################
# initialise counters
script_start_time = time.time()
trajectory_n = 1
accepted_designs = 0
rejected_designs = 0

### start design loop
while True:
    ### check if we have the target number of binders
    final_designs_reached = check_accepted_designs(design_paths, mpnn_csv, final_labels, final_csv, advanced_settings, target_settings, design_labels)

    if final_designs_reached:
        # stop design loop execution
        break

    ### check if we reached maximum allowed trajectories
    max_trajectories_reached = check_n_trajectories(design_paths, advanced_settings)

    if max_trajectories_reached:
        break

    ### Initialise design
    # measure time to generate design
    trajectory_start_time = time.time()

    # generate random seed to vary designs
    seed = int(np.random.randint(0, high=999999, size=1, dtype=int)[0])

    # sample binder design length randomly from defined distribution
    samples = np.arange(min(target_settings["lengths"]), max(target_settings["lengths"]) + 1)
    length = np.random.choice(samples)

    # load desired helicity value to sample different secondary structure contents
    helicity_value = load_helicity(advanced_settings)

    # generate design name and check if same trajectory was already run
    design_name = target_settings["binder_name"] + "_l" + str(length) + "_s"+ str(seed)
    trajectory_dirs = ["Trajectory", "Trajectory/Relaxed", "Trajectory/LowConfidence", "Trajectory/Clashing"]
    trajectory_exists = any(os.path.exists(os.path.join(design_paths[trajectory_dir], design_name + ".pdb")) for trajectory_dir in trajectory_dirs)

    if not trajectory_exists:
        print("Starting trajectory: "+design_name)

        ### Begin binder hallucination
        trajectory = binder_hallucination(design_name, target_settings["starting_pdb"], target_settings["chains"],
                                            target_settings["target_hotspot_residues"], length, seed, helicity_value,
                                            design_models, advanced_settings, design_paths, failure_csv)
        trajectory_metrics = copy_dict(trajectory.aux["log"]) # contains plddt, ptm, i_ptm, pae, i_pae
        trajectory_pdb = os.path.join(design_paths["Trajectory"], design_name + ".pdb")

        # round the metrics to two decimal places
        trajectory_metrics = {k: round(v, 2) if isinstance(v, float) else v for k, v in trajectory_metrics.items()}

        # time trajectory
        trajectory_time = time.time() - trajectory_start_time
        trajectory_time_text = f"{'%d hours, %d minutes, %d seconds' % (int(trajectory_time // 3600), int((trajectory_time % 3600) // 60), int(trajectory_time % 60))}"
        print("Starting trajectory took: "+trajectory_time_text)
        print("")

        # Proceed if there is no trajectory termination signal
        if trajectory_metrics['terminate'] == "":
            # Relax binder to calculate statistics
            trajectory_relaxed = os.path.join(design_paths["Trajectory/Relaxed"], design_name + ".pdb")
            pr_relax(trajectory_pdb, trajectory_relaxed)

            # define binder chain, placeholder in case multi-chain parsing in ColabDesign gets changed
            binder_chain = "B"

            # Calculate clashes before and after relaxation
            num_clashes_trajectory = calculate_clash_score(trajectory_pdb)
            num_clashes_relaxed = calculate_clash_score(trajectory_relaxed)

            # secondary structure content of starting trajectory binder and interface
            trajectory_alpha, trajectory_beta, trajectory_loops, trajectory_alpha_interface, trajectory_beta_interface, trajectory_loops_interface, trajectory_i_plddt, trajectory_ss_plddt = calc_ss_percentage(trajectory_pdb, advanced_settings, binder_chain)

            # analyze interface scores for relaxed af2 trajectory
            trajectory_interface_scores, trajectory_interface_AA, trajectory_interface_residues = score_interface(trajectory_relaxed, binder_chain)

            # starting binder sequence
            trajectory_sequence = trajectory.get_seq(get_best=True)[0]

            # analyze sequence
            traj_seq_notes = validate_design_sequence(trajectory_sequence, num_clashes_relaxed, advanced_settings)

            # target structure RMSD compared to input PDB
            trajectory_target_rmsd = unaligned_rmsd(target_settings["starting_pdb"], trajectory_pdb, target_settings["chains"], 'A')

            # save trajectory statistics into CSV
            trajectory_data = [design_name, advanced_settings["design_algorithm"], length, seed, helicity_value, target_settings["target_hotspot_residues"], trajectory_sequence, trajectory_interface_residues,
                                trajectory_metrics['plddt'], trajectory_metrics['ptm'], trajectory_metrics['i_ptm'], trajectory_metrics['pae'], trajectory_metrics['i_pae'],
                                trajectory_i_plddt, trajectory_ss_plddt, num_clashes_trajectory, num_clashes_relaxed, trajectory_interface_scores['binder_score'],
                                trajectory_interface_scores['surface_hydrophobicity'], trajectory_interface_scores['interface_sc'], trajectory_interface_scores['interface_packstat'],
                                trajectory_interface_scores['interface_dG'], trajectory_interface_scores['interface_dSASA'], trajectory_interface_scores['interface_dG_SASA_ratio'],
                                trajectory_interface_scores['interface_fraction'], trajectory_interface_scores['interface_hydrophobicity'], trajectory_interface_scores['interface_nres'], trajectory_interface_scores['interface_interface_hbonds'],
                                trajectory_interface_scores['interface_hbond_percentage'], trajectory_interface_scores['interface_delta_unsat_hbonds'], trajectory_interface_scores['interface_delta_unsat_hbonds_percentage'],
                                trajectory_alpha_interface, trajectory_beta_interface, trajectory_loops_interface, trajectory_alpha, trajectory_beta, trajectory_loops, trajectory_interface_AA, trajectory_target_rmsd,
                                trajectory_time_text, traj_seq_notes, settings_file, filters_file, advanced_file]
            insert_data(trajectory_csv, trajectory_data)

            if advanced_settings["enable_mpnn"]:
                # initialise MPNN counters
                mpnn_n = 1
                accepted_mpnn = 0
                mpnn_dict = {}
                design_start_time = time.time()

                ### MPNN redesign of starting binder
                mpnn_trajectories = mpnn_gen_sequence(trajectory_pdb, binder_chain, trajectory_interface_residues, advanced_settings)

                # whether to hard reject sequences with excluded amino acids
                if advanced_settings["force_reject_AA"]:
                    restricted_AAs = set(advanced_settings["omit_AAs"].split(','))
                    mpnn_sequences = [{'seq': mpnn_trajectories['seq'][n][-length:], 'score': mpnn_trajectories['score'][n], 'seqid': mpnn_trajectories['seqid'][n]}
                        for n in range(advanced_settings["num_seqs"])
                        if not any(restricted_AA in mpnn_trajectories['seq'][n] for restricted_AA in restricted_AAs)]
                else:
                    mpnn_sequences = [{'seq': mpnn_trajectories['seq'][n][-length:], 'score': mpnn_trajectories['score'][n], 'seqid': mpnn_trajectories['seqid'][n]}
                        for n in range(advanced_settings["num_seqs"])]

                # sort MPNN sequences by lowest MPNN score
                mpnn_sequences.sort(key=lambda x: x['score'])

                # add optimisation for increasing recycles if trajectory is beta sheeted
                if advanced_settings["optimise_beta"] and float(trajectory_beta) > 15:
                    advanced_settings["num_recycles_validation"] = advanced_settings["optimise_beta_recycles_valid"]

                ### Compile prediction models once for faster prediction of MPNN sequences
                clear_mem()
                # compile complex prediction model
                complex_prediction_model = mk_afdesign_model(protocol="binder", num_recycles=advanced_settings["num_recycles_validation"], data_dir=advanced_settings["af_params_dir"],
                                                            use_multimer=multimer_validation)
                complex_prediction_model.prep_inputs(pdb_filename=target_settings["starting_pdb"], chain=target_settings["chains"], binder_len=length, rm_target_seq=advanced_settings["rm_template_seq_predict"],
                                                    rm_target_sc=advanced_settings["rm_template_sc_predict"])

                # compile binder monomer prediction model
                binder_prediction_model = mk_afdesign_model(protocol="hallucination", use_templates=False, initial_guess=False,
                                                            use_initial_atom_pos=False, num_recycles=advanced_settings["num_recycles_validation"],
                                                            data_dir=advanced_settings["af_params_dir"], use_multimer=multimer_validation)
                binder_prediction_model.prep_inputs(length=length)

                # iterate over designed sequences
                for mpnn_sequence in mpnn_sequences:
                    mpnn_time = time.time()

                    # compile sequences dictionary with scores and remove duplicate sequences
                    if mpnn_sequence['seq'] not in [v['seq'] for v in mpnn_dict.values()]:
                        # generate mpnn design name numbering
                        mpnn_design_name = design_name + "_mpnn" + str(mpnn_n)
                        mpnn_score = round(mpnn_sequence['score'],2)
                        mpnn_seqid = round(mpnn_sequence['seqid'],2)

                        # add design to dictionary
                        mpnn_dict[mpnn_design_name] = {'seq': mpnn_sequence['seq'], 'score': mpnn_score, 'seqid': mpnn_seqid}

                        # save fasta sequence
                        if advanced_settings["save_mpnn_fasta"] is True:
                            save_fasta(mpnn_design_name, mpnn_sequence['seq'], design_paths)

                        ### Predict mpnn redesigned binder complex using masked templates
                        mpnn_complex_statistics, pass_af2_filters = masked_binder_predict(complex_prediction_model,
                                                                                        mpnn_sequence['seq'], mpnn_design_name,
                                                                                        target_settings["starting_pdb"], target_settings["chains"],
                                                                                        length, trajectory_pdb, prediction_models, advanced_settings,
                                                                                        filters, design_paths, failure_csv)

                        # if AF2 filters are not passed then skip the scoring
                        if not pass_af2_filters:
                            print(f"Base AF2 filters not passed for {mpnn_design_name}, skipping interface scoring")
                            continue

                        # calculate statistics for each model individually
                        for model_num in prediction_models:
                            mpnn_design_pdb = os.path.join(design_paths["MPNN"], f"{mpnn_design_name}_model{model_num+1}.pdb")
                            mpnn_design_relaxed = os.path.join(design_paths["MPNN/Relaxed"], f"{mpnn_design_name}_model{model_num+1}.pdb")

                            if os.path.exists(mpnn_design_pdb):
                                # Calculate clashes before and after relaxation
                                num_clashes_mpnn = calculate_clash_score(mpnn_design_pdb)
                                num_clashes_mpnn_relaxed = calculate_clash_score(mpnn_design_relaxed)

                                # analyze interface scores for relaxed af2 trajectory
                                mpnn_interface_scores, mpnn_interface_AA, mpnn_interface_residues = score_interface(mpnn_design_relaxed, binder_chain)

                                # secondary structure content of starting trajectory binder
                                mpnn_alpha, mpnn_beta, mpnn_loops, mpnn_alpha_interface, mpnn_beta_interface, mpnn_loops_interface, mpnn_i_plddt, mpnn_ss_plddt = calc_ss_percentage(mpnn_design_pdb, advanced_settings, binder_chain)

                                # unaligned RMSD calculate to determine if binder is in the designed binding site
                                rmsd_site = unaligned_rmsd(trajectory_pdb, mpnn_design_pdb, binder_chain, binder_chain)

                                # calculate RMSD of target compared to input PDB
                                target_rmsd = unaligned_rmsd(target_settings["starting_pdb"], mpnn_design_pdb, target_settings["chains"], 'A')

                                # add the additional statistics to the mpnn_complex_statistics dictionary
                                mpnn_complex_statistics[model_num+1].update({
                                    'i_pLDDT': mpnn_i_plddt,
                                    'ss_pLDDT': mpnn_ss_plddt,
                                    'Unrelaxed_Clashes': num_clashes_mpnn,
                                    'Relaxed_Clashes': num_clashes_mpnn_relaxed,
                                    'Binder_Energy_Score': mpnn_interface_scores['binder_score'],
                                    'Surface_Hydrophobicity': mpnn_interface_scores['surface_hydrophobicity'],
                                    'ShapeComplementarity': mpnn_interface_scores['interface_sc'],
                                    'PackStat': mpnn_interface_scores['interface_packstat'],
                                    'dG': mpnn_interface_scores['interface_dG'],
                                    'dSASA': mpnn_interface_scores['interface_dSASA'],
                                    'dG/dSASA': mpnn_interface_scores['interface_dG_SASA_ratio'],
                                    'Interface_SASA_%': mpnn_interface_scores['interface_fraction'],
                                    'Interface_Hydrophobicity': mpnn_interface_scores['interface_hydrophobicity'],
                                    'n_InterfaceResidues': mpnn_interface_scores['interface_nres'],
                                    'n_InterfaceHbonds': mpnn_interface_scores['interface_interface_hbonds'],
                                    'InterfaceHbondsPercentage': mpnn_interface_scores['interface_hbond_percentage'],
                                    'n_InterfaceUnsatHbonds': mpnn_interface_scores['interface_delta_unsat_hbonds'],
                                    'InterfaceUnsatHbondsPercentage': mpnn_interface_scores['interface_delta_unsat_hbonds_percentage'],
                                    'InterfaceAAs': mpnn_interface_AA,
                                    'Interface_Helix%': mpnn_alpha_interface,
                                    'Interface_BetaSheet%': mpnn_beta_interface,
                                    'Interface_Loop%': mpnn_loops_interface,
                                    'Binder_Helix%': mpnn_alpha,
                                    'Binder_BetaSheet%': mpnn_beta,
                                    'Binder_Loop%': mpnn_loops,
                                    'Hotspot_RMSD': rmsd_site,
                                    'Target_RMSD': target_rmsd
                                })

                                # save space by removing unrelaxed predicted mpnn complex pdb?
                                if advanced_settings["remove_unrelaxed_complex"]:
                                    os.remove(mpnn_design_pdb)

                        # calculate complex averages
                        mpnn_complex_averages = calculate_averages(mpnn_complex_statistics, handle_aa=True)

                        ### Predict binder alone in single sequence mode
                        binder_statistics = predict_binder_alone(binder_prediction_model, mpnn_sequence['seq'], mpnn_design_name, length,
                                                                trajectory_pdb, binder_chain, prediction_models, advanced_settings, design_paths)

                        # extract RMSDs of binder to the original trajectory
                        for model_num in prediction_models:
                            mpnn_binder_pdb = os.path.join(design_paths["MPNN/Binder"], f"{mpnn_design_name}_model{model_num+1}.pdb")

                            if os.path.exists(mpnn_binder_pdb):
                                rmsd_binder = unaligned_rmsd(trajectory_pdb, mpnn_binder_pdb, binder_chain, "A")

                            # append to statistics
                            binder_statistics[model_num+1].update({
                                    'Binder_RMSD': rmsd_binder
                                })

                            # save space by removing binder monomer models?
                            if advanced_settings["remove_binder_monomer"]:
                                os.remove(mpnn_binder_pdb)

                        # calculate binder averages
                        binder_averages = calculate_averages(binder_statistics)

                        # analyze sequence to make sure there are no cysteins and it contains residues that absorb UV for detection
                        seq_notes = validate_design_sequence(mpnn_sequence['seq'], mpnn_complex_averages.get('Relaxed_Clashes', None), advanced_settings)

                        # measure time to generate design
                        mpnn_end_time = time.time() - mpnn_time
                        elapsed_mpnn_text = f"{'%d hours, %d minutes, %d seconds' % (int(mpnn_end_time // 3600), int((mpnn_end_time % 3600) // 60), int(mpnn_end_time % 60))}"


                        # Insert statistics about MPNN design into CSV, will return None if corresponding model does note exist
                        model_numbers = range(1, 6)
                        statistics_labels = ['pLDDT', 'pTM', 'i_pTM', 'pAE', 'i_pAE', 'i_pLDDT', 'ss_pLDDT', 'Unrelaxed_Clashes', 'Relaxed_Clashes', 'Binder_Energy_Score', 'Surface_Hydrophobicity',
                                            'ShapeComplementarity', 'PackStat', 'dG', 'dSASA', 'dG/dSASA', 'Interface_SASA_%', 'Interface_Hydrophobicity', 'n_InterfaceResidues', 'n_InterfaceHbonds', 'InterfaceHbondsPercentage',
                                            'n_InterfaceUnsatHbonds', 'InterfaceUnsatHbondsPercentage', 'Interface_Helix%', 'Interface_BetaSheet%', 'Interface_Loop%', 'Binder_Helix%',
                                            'Binder_BetaSheet%', 'Binder_Loop%', 'InterfaceAAs', 'Hotspot_RMSD', 'Target_RMSD']

                        # Initialize mpnn_data with the non-statistical data
                        mpnn_data = [mpnn_design_name, advanced_settings["design_algorithm"], length, seed, helicity_value, target_settings["target_hotspot_residues"], mpnn_sequence['seq'], mpnn_interface_residues, mpnn_score, mpnn_seqid]

                        # Add the statistical data for mpnn_complex
                        for label in statistics_labels:
                            mpnn_data.append(mpnn_complex_averages.get(label, None))
                            for model in model_numbers:
                                mpnn_data.append(mpnn_complex_statistics.get(model, {}).get(label, None))

                        # Add the statistical data for binder
                        for label in ['pLDDT', 'pTM', 'pAE', 'Binder_RMSD']:  # These are the labels for binder alone
                            mpnn_data.append(binder_averages.get(label, None))
                            for model in model_numbers:
                                mpnn_data.append(binder_statistics.get(model, {}).get(label, None))

                        # Add the remaining non-statistical data
                        mpnn_data.extend([elapsed_mpnn_text, seq_notes, settings_file, filters_file, advanced_file])

                        # insert data into csv
                        insert_data(mpnn_csv, mpnn_data)

                        # find best model number by pLDDT
                        plddt_values = {i: mpnn_data[i] for i in range(11, 15) if mpnn_data[i] is not None}

                        # Find the key with the highest value
                        highest_plddt_key = int(max(plddt_values, key=plddt_values.get))

                        # Output the number part of the key
                        best_model_number = highest_plddt_key - 10
                        best_model_pdb = os.path.join(design_paths["MPNN/Relaxed"], f"{mpnn_design_name}_model{best_model_number}.pdb")

                        # run design data against filter thresholds
                        filter_conditions = check_filters(mpnn_data, design_labels, filters)
                        if filter_conditions == True:
                            print(mpnn_design_name+" passed all filters")
                            accepted_mpnn += 1
                            accepted_designs += 1

                            # copy designs to accepted folder
                            shutil.copy(best_model_pdb, design_paths["Accepted"])

                            # insert data into final csv
                            final_data = [''] + mpnn_data
                            insert_data(final_csv, final_data)

                            # copy animation from accepted trajectory
                            accepted_animation = os.path.join(design_paths["Accepted/Animation"], f"{design_name}.html")
                            if not os.path.exists(accepted_animation):
                                shutil.copy(os.path.join(design_paths["Trajectory/Animation"], f"{design_name}.html"), accepted_animation)

                            # copy plots of accepted trajectory
                            plot_files = os.listdir(design_paths["Trajectory/Plots"])
                            plots_to_copy = [f for f in plot_files if f.startswith(design_name) and f.endswith('.png')]
                            for accepted_plot in plots_to_copy:
                                source_plot = os.path.join(design_paths["Trajectory/Plots"], accepted_plot)
                                target_plot = os.path.join(design_paths["Accepted/Plots"], accepted_plot)
                                if not os.path.exists(target_plot):
                                    shutil.copy(source_plot, target_plot)

                        else:
                            print(f"Unmet filter conditions for {mpnn_design_name}")
                            failure_df = pd.read_csv(failure_csv)
                            special_prefixes = ('Average_', '1_', '2_', '3_', '4_', '5_')
                            incremented_columns = set()

                            for column in filter_conditions:
                                base_column = column
                                for prefix in special_prefixes:
                                    if column.startswith(prefix):
                                        base_column = column.split('_', 1)[1]

                                if base_column not in incremented_columns:
                                    failure_df[base_column] = failure_df[base_column] + 1
                                    incremented_columns.add(base_column)

                            failure_df.to_csv(failure_csv, index=False)
                            shutil.copy(best_model_pdb, design_paths["Rejected"])

                        # increase MPNN design number
                        mpnn_n += 1

                        # if enough mpnn sequences of the same trajectory pass filters then stop
                        if accepted_mpnn >= advanced_settings["max_mpnn_sequences"]:
                            break
                    else:
                        print("Skipping duplicate sequence")

                if accepted_mpnn >= 1:
                    print("Found "+str(accepted_mpnn)+" MPNN designs passing filters")
                else:
                    print("No accepted MPNN designs found for this trajectory.")
                    rejected_designs += 1

                # save space by removing unrelaxed design trajectory PDB
                if advanced_settings["remove_unrelaxed_trajectory"]:
                    os.remove(trajectory_pdb)

                # measure time it took to generate designs for one trajectory
                design_time = time.time() - design_start_time
                design_time_text = f"{'%d hours, %d minutes, %d seconds' % (int(design_time // 3600), int((design_time % 3600) // 60), int(design_time % 60))}"
                print("Design and validation of trajectory "+design_name+" took: "+design_time_text)

            # analyse the rejection rate of trajectories to see if we need to readjust the design weights
            if trajectory_n >= advanced_settings["start_monitoring"] and advanced_settings["enable_rejection_check"]:
                acceptance = accepted_designs / trajectory_n
                if not acceptance >= advanced_settings["acceptance_rate"]:
                    print("The ratio of successful designs is lower than defined acceptance rate! Consider changing your design settings!")
                    print("Script execution stopping...")
                    break

        # increase trajectory number
        trajectory_n += 1

### Script finished
elapsed_time = time.time() - script_start_time
elapsed_text = f"{'%d hours, %d minutes, %d seconds' % (int(elapsed_time // 3600), int((elapsed_time % 3600) // 60), int(elapsed_time % 60))}"
print("Finished all designs. Script execution for "+str(trajectory_n)+" trajectories took: "+elapsed_text)
# Out:
# Starting trajectory: 6ARU_l48_s241256
# Stage 1: Test Logits
# 1 models [3] recycles 1 hard 0 soft 0.02 temp 1 loss 9.35 helix 1.39 pae 0.70 i_pae 0.73 con 4.25 i_con 4.13 plddt 0.29 ptm 0.78 i_ptm 0.21 rg 3.09
# 2 models [0] recycles 1 hard 0 soft 0.04 temp 1 loss 8.41 helix 0.87 pae 0.66 i_pae 0.71 con 4.07 i_con 4.15 plddt 0.34 ptm 0.77 i_ptm 0.20 rg 0.05
# 3 models [1] recycles 1 hard 0 soft 0.05 temp 1 loss 8.52 helix 0.85 pae 0.61 i_pae 0.65 con 4.08 i_con 3.97 plddt 0.41 ptm 0.79 i_ptm 0.25 rg 1.04
# 4 models [4] recycles 1 hard 0 soft 0.07 temp 1 loss 8.30 helix 0.80 pae 0.64 i_pae 0.69 con 3.87 i_con 4.05 plddt 0.40 ptm 0.78 i_ptm 0.23 rg 0.67
# 5 models [1] recycles 1 hard 0 soft 0.09 temp 1 loss 7.61 helix 0.65 pae 0.50 i_pae 0.54 con 3.41 i_con 3.65 plddt 0.53 ptm 0.81 i_ptm 0.37 rg 1.36
# 6 models [4] recycles 1 hard 0 soft 0.11 temp 1 loss 7.32 helix 0.62 pae 0.49 i_pae 0.55 con 3.23 i_con 3.55 plddt 0.55 ptm 0.80 i_ptm 0.34 rg 1.31
# 7 models [4] recycles 1 hard 0 soft 0.13 temp 1 loss 6.55 helix 0.64 pae 0.37 i_pae 0.42 con 2.72 i_con 3.19 plddt 0.71 ptm 0.83 i_ptm 0.49 rg 1.97
# 8 models [4] recycles 1 hard 0 soft 0.14 temp 1 loss 5.30 helix 0.72 pae 0.20 i_pae 0.22 con 2.25 i_con 2.49 plddt 0.84 ptm 0.88 i_ptm 0.77 rg 2.15
# 9 models [0] recycles 1 hard 0 soft 0.16 temp 1 loss 5.26 helix 0.76 pae 0.23 i_pae 0.25 con 2.08 i_con 2.62 plddt 0.82 ptm 0.87 i_ptm 0.72 rg 2.13
# 10 models [4] recycles 1 hard 0 soft 0.18 temp 1 loss 4.59 helix 0.77 pae 0.15 i_pae 0.16 con 1.97 i_con 2.09 plddt 0.90 ptm 0.90 i_ptm 0.86 rg 2.21
# 11 models [0] recycles 1 hard 0 soft 0.20 temp 1 loss 4.68 helix 0.81 pae 0.17 i_pae 0.18 con 1.90 i_con 2.26 plddt 0.87 ptm 0.89 i_ptm 0.82 rg 2.19
# 12 models [4] recycles 1 hard 0 soft 0.22 temp 1 loss 4.57 helix 0.87 pae 0.15 i_pae 0.17 con 1.96 i_con 2.10 plddt 0.89 ptm 0.91 i_ptm 0.85 rg 2.23
# 13 models [4] recycles 1 hard 0 soft 0.23 temp 1 loss 4.44 helix 0.86 pae 0.15 i_pae 0.17 con 1.88 i_con 2.07 plddt 0.90 ptm 0.91 i_ptm 0.86 rg 2.19
# 14 models [2] recycles 1 hard 0 soft 0.25 temp 1 loss 4.56 helix 0.97 pae 0.16 i_pae 0.18 con 1.89 i_con 2.16 plddt 0.90 ptm 0.90 i_ptm 0.84 rg 2.31
# 15 models [4] recycles 1 hard 0 soft 0.27 temp 1 loss 4.10 helix 0.86 pae 0.13 i_pae 0.14 con 1.81 i_con 1.81 plddt 0.93 ptm 0.91 i_ptm 0.89 rg 2.18
# 16 models [4] recycles 1 hard 0 soft 0.29 temp 1 loss 4.19 helix 0.93 pae 0.13 i_pae 0.14 con 1.82 i_con 1.89 plddt 0.92 ptm 0.91 i_ptm 0.89 rg 2.26
# 17 models [4] recycles 1 hard 0 soft 0.31 temp 1 loss 3.89 helix 0.98 pae 0.12 i_pae 0.13 con 1.74 i_con 1.70 plddt 0.94 ptm 0.92 i_ptm 0.90 rg 2.24
# 18 models [1] recycles 1 hard 0 soft 0.32 temp 1 loss 8.95 helix 0.74 pae 0.57 i_pae 0.60 con 4.16 i_con 3.89 plddt 0.54 ptm 0.80 i_ptm 0.33 rg 2.54
# 19 models [2] recycles 1 hard 0 soft 0.34 temp 1 loss 4.11 helix 1.05 pae 0.13 i_pae 0.14 con 1.92 i_con 1.79 plddt 0.93 ptm 0.92 i_ptm 0.89 rg 2.12
# 20 models [4] recycles 1 hard 0 soft 0.36 temp 1 loss 3.71 helix 1.02 pae 0.11 i_pae 0.13 con 1.68 i_con 1.65 plddt 0.94 ptm 0.92 i_ptm 0.90 rg 2.08
# 21 models [0] recycles 1 hard 0 soft 0.38 temp 1 loss 4.14 helix 0.91 pae 0.13 i_pae 0.15 con 1.81 i_con 1.86 plddt 0.91 ptm 0.91 i_ptm 0.88 rg 2.21
# 22 models [2] recycles 1 hard 0 soft 0.40 temp 1 loss 4.16 helix 0.91 pae 0.14 i_pae 0.16 con 1.79 i_con 1.93 plddt 0.91 ptm 0.90 i_ptm 0.87 rg 2.06
# 23 models [1] recycles 1 hard 0 soft 0.41 temp 1 loss 4.43 helix 1.02 pae 0.15 i_pae 0.16 con 2.02 i_con 1.99 plddt 0.89 ptm 0.91 i_ptm 0.87 rg 2.13
# 24 models [1] recycles 1 hard 0 soft 0.43 temp 1 loss 4.22 helix 0.86 pae 0.14 i_pae 0.15 con 1.83 i_con 1.92 plddt 0.90 ptm 0.91 i_ptm 0.88 rg 2.15
# 25 models [0] recycles 1 hard 0 soft 0.45 temp 1 loss 4.06 helix 1.02 pae 0.13 i_pae 0.15 con 1.77 i_con 1.89 plddt 0.91 ptm 0.91 i_ptm 0.88 rg 2.09
# 26 models [2] recycles 1 hard 0 soft 0.47 temp 1 loss 4.07 helix 0.93 pae 0.14 i_pae 0.15 con 1.79 i_con 1.87 plddt 0.92 ptm 0.90 i_ptm 0.87 rg 2.04
# 27 models [4] recycles 1 hard 0 soft 0.49 temp 1 loss 3.94 helix 0.96 pae 0.13 i_pae 0.14 con 1.75 i_con 1.77 plddt 0.93 ptm 0.91 i_ptm 0.89 rg 2.10
# 28 models [2] recycles 1 hard 0 soft 0.50 temp 1 loss 3.94 helix 0.97 pae 0.13 i_pae 0.14 con 1.77 i_con 1.76 plddt 0.93 ptm 0.91 i_ptm 0.89 rg 2.09
# 29 models [2] recycles 1 hard 0 soft 0.52 temp 1 loss 4.12 helix 0.96 pae 0.14 i_pae 0.16 con 1.77 i_con 1.92 plddt 0.92 ptm 0.90 i_ptm 0.87 rg 2.12
# 30 models [3] recycles 1 hard 0 soft 0.54 temp 1 loss 3.93 helix 0.78 pae 0.13 i_pae 0.14 con 1.71 i_con 1.75 plddt 0.92 ptm 0.92 i_ptm 0.90 rg 2.09
# 31 models [3] recycles 1 hard 0 soft 0.56 temp 1 loss 3.81 helix 0.98 pae 0.12 i_pae 0.13 con 1.65 i_con 1.75 plddt 0.93 ptm 0.92 i_ptm 0.89 rg 2.12
# 32 models [3] recycles 1 hard 0 soft 0.58 temp 1 loss 3.77 helix 0.96 pae 0.12 i_pae 0.13 con 1.66 i_con 1.69 plddt 0.94 ptm 0.92 i_ptm 0.90 rg 2.11
# 33 models [2] recycles 1 hard 0 soft 0.59 temp 1 loss 3.95 helix 1.00 pae 0.13 i_pae 0.14 con 1.73 i_con 1.80 plddt 0.93 ptm 0.92 i_ptm 0.89 rg 2.15
# 34 models [2] recycles 1 hard 0 soft 0.61 temp 1 loss 3.72 helix 1.04 pae 0.12 i_pae 0.13 con 1.69 i_con 1.64 plddt 0.95 ptm 0.92 i_ptm 0.90 rg 2.11
# 35 models [3] recycles 1 hard 0 soft 0.63 temp 1 loss 3.64 helix 0.98 pae 0.11 i_pae 0.12 con 1.64 i_con 1.59 plddt 0.95 ptm 0.92 i_ptm 0.91 rg 2.14
# 36 models [4] recycles 1 hard 0 soft 0.65 temp 1 loss 3.73 helix 1.02 pae 0.11 i_pae 0.12 con 1.64 i_con 1.69 plddt 0.95 ptm 0.92 i_ptm 0.90 rg 2.14
# 37 models [1] recycles 1 hard 0 soft 0.67 temp 1 loss 4.14 helix 0.93 pae 0.13 i_pae 0.15 con 1.72 i_con 1.97 plddt 0.91 ptm 0.91 i_ptm 0.87 rg 2.13
# 38 models [2] recycles 1 hard 0 soft 0.68 temp 1 loss 3.55 helix 1.08 pae 0.11 i_pae 0.12 con 1.58 i_con 1.60 plddt 0.95 ptm 0.92 i_ptm 0.91 rg 2.11
# 39 models [4] recycles 1 hard 0 soft 0.70 temp 1 loss 3.57 helix 1.00 pae 0.11 i_pae 0.12 con 1.56 i_con 1.61 plddt 0.95 ptm 0.92 i_ptm 0.91 rg 2.13
# 40 models [0] recycles 1 hard 0 soft 0.72 temp 1 loss 3.66 helix 0.90 pae 0.12 i_pae 0.13 con 1.56 i_con 1.67 plddt 0.94 ptm 0.92 i_ptm 0.90 rg 2.12
# 41 models [4] recycles 1 hard 0 soft 0.74 temp 1 loss 3.67 helix 0.95 pae 0.12 i_pae 0.13 con 1.56 i_con 1.67 plddt 0.94 ptm 0.92 i_ptm 0.90 rg 2.15
# 42 models [3] recycles 1 hard 0 soft 0.76 temp 1 loss 3.49 helix 1.05 pae 0.11 i_pae 0.12 con 1.57 i_con 1.54 plddt 0.95 ptm 0.93 i_ptm 0.91 rg 2.13
# 43 models [3] recycles 1 hard 0 soft 0.77 temp 1 loss 3.53 helix 1.03 pae 0.11 i_pae 0.12 con 1.55 i_con 1.57 plddt 0.95 ptm 0.92 i_ptm 0.91 rg 2.19
# 44 models [2] recycles 1 hard 0 soft 0.79 temp 1 loss 3.59 helix 1.07 pae 0.11 i_pae 0.13 con 1.56 i_con 1.63 plddt 0.95 ptm 0.92 i_ptm 0.90 rg 2.14
# 45 models [4] recycles 1 hard 0 soft 0.81 temp 1 loss 3.84 helix 1.01 pae 0.12 i_pae 0.13 con 1.62 i_con 1.78 plddt 0.94 ptm 0.92 i_ptm 0.89 rg 2.22
# 46 models [0] recycles 1 hard 0 soft 0.83 temp 1 loss 3.87 helix 0.96 pae 0.13 i_pae 0.14 con 1.61 i_con 1.84 plddt 0.92 ptm 0.91 i_ptm 0.88 rg 2.12
# 47 models [4] recycles 1 hard 0 soft 0.85 temp 1 loss 3.43 helix 1.07 pae 0.11 i_pae 0.12 con 1.51 i_con 1.52 plddt 0.96 ptm 0.92 i_ptm 0.91 rg 2.15
# 48 models [2] recycles 1 hard 0 soft 0.86 temp 1 loss 3.63 helix 1.05 pae 0.11 i_pae 0.12 con 1.60 i_con 1.64 plddt 0.95 ptm 0.92 i_ptm 0.91 rg 2.10
# 49 models [1] recycles 1 hard 0 soft 0.88 temp 1 loss 8.53 helix 0.83 pae 0.64 i_pae 0.68 con 3.99 i_con 4.17 plddt 0.39 ptm 0.78 i_ptm 0.23 rg 0.64
# 50 models [2] recycles 1 hard 0 soft 0.90 temp 1 loss 4.76 helix 0.90 pae 0.17 i_pae 0.19 con 2.03 i_con 2.27 plddt 0.87 ptm 0.90 i_ptm 0.83 rg 2.09
# Initial trajectory pLDDT good, continuing: 0.96
# Stage 1: Additional Logits Optimisation
# 51 models [3] recycles 1 hard 0 soft 0.04 temp 1 loss 8.41 helix 1.85 pae 0.74 i_pae 0.76 con 4.41 i_con 4.29 plddt 0.24 ptm 0.77 i_ptm 0.18 rg -0.75
# 52 models [3] recycles 1 hard 0 soft 0.08 temp 1 loss 8.50 helix 1.21 pae 0.70 i_pae 0.73 con 4.32 i_con 4.11 plddt 0.31 ptm 0.77 i_ptm 0.19 rg -0.08
# 53 models [4] recycles 1 hard 0 soft 0.12 temp 1 loss 8.22 helix 1.25 pae 0.69 i_pae 0.73 con 4.27 i_con 4.12 plddt 0.30 ptm 0.78 i_ptm 0.19 rg -0.86
# 54 models [3] recycles 1 hard 0 soft 0.16 temp 1 loss 3.55 helix 1.04 pae 0.12 i_pae 0.13 con 1.57 i_con 1.57 plddt 0.95 ptm 0.92 i_ptm 0.91 rg 2.19
# 55 models [4] recycles 1 hard 0 soft 0.20 temp 1 loss 8.05 helix 1.61 pae 0.69 i_pae 0.72 con 4.34 i_con 4.00 plddt 0.27 ptm 0.77 i_ptm 0.20 rg -0.88
# 56 models [4] recycles 1 hard 0 soft 0.24 temp 1 loss 7.76 helix 1.07 pae 0.64 i_pae 0.67 con 4.05 i_con 3.86 plddt 0.34 ptm 0.77 i_ptm 0.23 rg -0.84
# 57 models [3] recycles 1 hard 0 soft 0.28 temp 1 loss 3.48 helix 1.03 pae 0.11 i_pae 0.12 con 1.55 i_con 1.55 plddt 0.95 ptm 0.92 i_ptm 0.91 rg 2.08
# 58 models [0] recycles 1 hard 0 soft 0.32 temp 1 loss 3.36 helix 1.12 pae 0.11 i_pae 0.12 con 1.51 i_con 1.50 plddt 0.96 ptm 0.92 i_ptm 0.91 rg 2.08
# 59 models [1] recycles 1 hard 0 soft 0.36 temp 1 loss 3.22 helix 1.10 pae 0.10 i_pae 0.11 con 1.43 i_con 1.44 plddt 0.96 ptm 0.93 i_ptm 0.92 rg 2.07
# 60 models [0] recycles 1 hard 0 soft 0.40 temp 1 loss 3.34 helix 1.10 pae 0.11 i_pae 0.12 con 1.49 i_con 1.51 plddt 0.96 ptm 0.92 i_ptm 0.91 rg 2.07
# 61 models [3] recycles 1 hard 0 soft 0.44 temp 1 loss 3.14 helix 1.17 pae 0.10 i_pae 0.11 con 1.41 i_con 1.39 plddt 0.96 ptm 0.92 i_ptm 0.92 rg 2.10
# 62 models [0] recycles 1 hard 0 soft 0.48 temp 1 loss 3.30 helix 1.09 pae 0.11 i_pae 0.12 con 1.46 i_con 1.47 plddt 0.95 ptm 0.93 i_ptm 0.92 rg 2.10
# 63 models [1] recycles 1 hard 0 soft 0.52 temp 1 loss 3.28 helix 1.11 pae 0.10 i_pae 0.11 con 1.46 i_con 1.47 plddt 0.96 ptm 0.92 i_ptm 0.91 rg 2.09
# 64 models [3] recycles 1 hard 0 soft 0.56 temp 1 loss 3.17 helix 1.11 pae 0.10 i_pae 0.11 con 1.42 i_con 1.40 plddt 0.97 ptm 0.93 i_ptm 0.92 rg 2.09
# 65 models [3] recycles 1 hard 0 soft 0.60 temp 1 loss 3.16 helix 1.18 pae 0.10 i_pae 0.11 con 1.42 i_con 1.40 plddt 0.96 ptm 0.93 i_ptm 0.92 rg 2.12
# 66 models [3] recycles 1 hard 0 soft 0.64 temp 1 loss 3.13 helix 1.16 pae 0.10 i_pae 0.11 con 1.41 i_con 1.39 plddt 0.96 ptm 0.92 i_ptm 0.92 rg 2.07
# 67 models [3] recycles 1 hard 0 soft 0.68 temp 1 loss 3.28 helix 1.17 pae 0.10 i_pae 0.11 con 1.48 i_con 1.45 plddt 0.96 ptm 0.93 i_ptm 0.92 rg 2.12
# 68 models [2] recycles 1 hard 0 soft 0.72 temp 1 loss 3.32 helix 1.09 pae 0.11 i_pae 0.12 con 1.48 i_con 1.47 plddt 0.96 ptm 0.92 i_ptm 0.92 rg 2.10
# 69 models [0] recycles 1 hard 0 soft 0.76 temp 1 loss 3.37 helix 1.17 pae 0.11 i_pae 0.12 con 1.53 i_con 1.48 plddt 0.95 ptm 0.93 i_ptm 0.91 rg 2.14
# 70 models [4] recycles 1 hard 0 soft 0.80 temp 1 loss 3.50 helix 1.11 pae 0.11 i_pae 0.12 con 1.56 i_con 1.56 plddt 0.95 ptm 0.92 i_ptm 0.91 rg 2.17
# 71 models [1] recycles 1 hard 0 soft 0.84 temp 1 loss 3.34 helix 1.06 pae 0.11 i_pae 0.12 con 1.47 i_con 1.48 plddt 0.96 ptm 0.93 i_ptm 0.91 rg 2.12
# 72 models [2] recycles 1 hard 0 soft 0.88 temp 1 loss 3.59 helix 1.19 pae 0.12 i_pae 0.13 con 1.63 i_con 1.60 plddt 0.95 ptm 0.92 i_ptm 0.91 rg 2.17
# 73 models [4] recycles 1 hard 0 soft 0.92 temp 1 loss 3.67 helix 1.22 pae 0.12 i_pae 0.13 con 1.65 i_con 1.65 plddt 0.94 ptm 0.92 i_ptm 0.90 rg 2.20
# 74 models [1] recycles 1 hard 0 soft 0.96 temp 1 loss 4.56 helix 0.94 pae 0.16 i_pae 0.18 con 1.88 i_con 2.24 plddt 0.87 ptm 0.91 i_ptm 0.83 rg 2.06
# 75 models [2] recycles 1 hard 0 soft 1 temp 1 loss 3.91 helix 0.93 pae 0.13 i_pae 0.14 con 1.71 i_con 1.73 plddt 0.93 ptm 0.92 i_ptm 0.90 rg 2.21
# Optimised logit trajectory pLDDT: 0.96
# Stage 2: Softmax Optimisation
# 76 models [1] recycles 1 hard 0 soft 1 temp 0.96 loss 3.90 helix 0.99 pae 0.13 i_pae 0.14 con 1.71 i_con 1.78 plddt 0.92 ptm 0.92 i_ptm 0.89 rg 2.12
# 77 models [1] recycles 1 hard 0 soft 1 temp 0.91 loss 3.75 helix 0.98 pae 0.12 i_pae 0.13 con 1.62 i_con 1.70 plddt 0.93 ptm 0.92 i_ptm 0.90 rg 2.17
# 78 models [0] recycles 1 hard 0 soft 1 temp 0.87 loss 3.43 helix 1.04 pae 0.11 i_pae 0.12 con 1.51 i_con 1.54 plddt 0.95 ptm 0.92 i_ptm 0.91 rg 2.10
# 79 models [4] recycles 1 hard 0 soft 1 temp 0.83 loss 3.37 helix 1.06 pae 0.11 i_pae 0.12 con 1.48 i_con 1.52 plddt 0.95 ptm 0.92 i_ptm 0.91 rg 2.07
# 80 models [4] recycles 1 hard 0 soft 1 temp 0.79 loss 3.46 helix 1.06 pae 0.11 i_pae 0.12 con 1.53 i_con 1.55 plddt 0.95 ptm 0.93 i_ptm 0.91 rg 2.11
# 81 models [3] recycles 1 hard 0 soft 1 temp 0.75 loss 3.26 helix 1.11 pae 0.10 i_pae 0.12 con 1.47 i_con 1.44 plddt 0.96 ptm 0.93 i_ptm 0.92 rg 2.10
# 82 models [3] recycles 1 hard 0 soft 1 temp 0.72 loss 3.28 helix 1.11 pae 0.11 i_pae 0.12 con 1.47 i_con 1.46 plddt 0.96 ptm 0.93 i_ptm 0.92 rg 2.08
# 83 models [3] recycles 1 hard 0 soft 1 temp 0.68 loss 3.22 helix 1.10 pae 0.11 i_pae 0.12 con 1.44 i_con 1.43 plddt 0.96 ptm 0.93 i_ptm 0.92 rg 2.03
# 84 models [2] recycles 1 hard 0 soft 1 temp 0.64 loss 3.55 helix 1.05 pae 0.12 i_pae 0.13 con 1.54 i_con 1.60 plddt 0.95 ptm 0.92 i_ptm 0.91 rg 2.15
# 85 models [0] recycles 1 hard 0 soft 1 temp 0.61 loss 3.41 helix 1.07 pae 0.11 i_pae 0.12 con 1.52 i_con 1.52 plddt 0.95 ptm 0.92 i_ptm 0.91 rg 2.08
# 86 models [1] recycles 1 hard 0 soft 1 temp 0.58 loss 3.29 helix 1.06 pae 0.10 i_pae 0.11 con 1.46 i_con 1.45 plddt 0.96 ptm 0.93 i_ptm 0.92 rg 2.12
# 87 models [0] recycles 1 hard 0 soft 1 temp 0.54 loss 3.48 helix 1.11 pae 0.11 i_pae 0.13 con 1.53 i_con 1.59 plddt 0.94 ptm 0.92 i_ptm 0.90 rg 2.07
# 88 models [3] recycles 1 hard 0 soft 1 temp 0.51 loss 3.31 helix 1.11 pae 0.11 i_pae 0.12 con 1.47 i_con 1.48 plddt 0.96 ptm 0.92 i_ptm 0.91 rg 2.09
# 89 models [1] recycles 1 hard 0 soft 1 temp 0.48 loss 3.36 helix 1.10 pae 0.11 i_pae 0.12 con 1.47 i_con 1.54 plddt 0.95 ptm 0.93 i_ptm 0.91 rg 2.09
# 90 models [2] recycles 1 hard 0 soft 1 temp 0.45 loss 3.37 helix 1.14 pae 0.11 i_pae 0.12 con 1.52 i_con 1.51 plddt 0.96 ptm 0.92 i_ptm 0.91 rg 2.09
# 91 models [4] recycles 1 hard 0 soft 1 temp 0.42 loss 3.79 helix 1.03 pae 0.12 i_pae 0.14 con 1.61 i_con 1.79 plddt 0.93 ptm 0.92 i_ptm 0.89 rg 2.10
# 92 models [0] recycles 1 hard 0 soft 1 temp 0.39 loss 3.30 helix 1.14 pae 0.11 i_pae 0.12 con 1.46 i_con 1.50 plddt 0.95 ptm 0.92 i_ptm 0.91 rg 2.06
# 93 models [0] recycles 1 hard 0 soft 1 temp 0.37 loss 3.64 helix 1.02 pae 0.12 i_pae 0.13 con 1.53 i_con 1.68 plddt 0.93 ptm 0.92 i_ptm 0.90 rg 2.19
# 94 models [0] recycles 1 hard 0 soft 1 temp 0.34 loss 3.47 helix 1.14 pae 0.11 i_pae 0.12 con 1.54 i_con 1.58 plddt 0.95 ptm 0.92 i_ptm 0.91 rg 2.07
# 95 models [0] recycles 1 hard 0 soft 1 temp 0.32 loss 3.50 helix 1.03 pae 0.11 i_pae 0.12 con 1.56 i_con 1.55 plddt 0.94 ptm 0.93 i_ptm 0.91 rg 2.09
# 96 models [3] recycles 1 hard 0 soft 1 temp 0.29 loss 3.37 helix 1.09 pae 0.11 i_pae 0.12 con 1.50 i_con 1.52 plddt 0.96 ptm 0.93 i_ptm 0.92 rg 2.06
# 97 models [2] recycles 1 hard 0 soft 1 temp 0.27 loss 3.64 helix 1.05 pae 0.12 i_pae 0.13 con 1.61 i_con 1.62 plddt 0.94 ptm 0.92 i_ptm 0.91 rg 2.18
# 98 models [3] recycles 1 hard 0 soft 1 temp 0.25 loss 3.26 helix 1.14 pae 0.10 i_pae 0.11 con 1.44 i_con 1.46 plddt 0.96 ptm 0.93 i_ptm 0.92 rg 2.13
# 99 models [2] recycles 1 hard 0 soft 1 temp 0.23 loss 3.53 helix 1.18 pae 0.11 i_pae 0.12 con 1.59 i_con 1.59 plddt 0.95 ptm 0.92 i_ptm 0.91 rg 2.14
# 100 models [0] recycles 1 hard 0 soft 1 temp 0.21 loss 3.40 helix 1.16 pae 0.11 i_pae 0.12 con 1.51 i_con 1.55 plddt 0.95 ptm 0.92 i_ptm 0.91 rg 2.10
# 101 models [2] recycles 1 hard 0 soft 1 temp 0.19 loss 3.64 helix 1.07 pae 0.12 i_pae 0.13 con 1.60 i_con 1.66 plddt 0.95 ptm 0.92 i_ptm 0.90 rg 2.12
# 102 models [0] recycles 1 hard 0 soft 1 temp 0.17 loss 3.48 helix 1.13 pae 0.11 i_pae 0.12 con 1.56 i_con 1.56 plddt 0.95 ptm 0.92 i_ptm 0.91 rg 2.11
# 103 models [2] recycles 1 hard 0 soft 1 temp 0.15 loss 3.69 helix 1.14 pae 0.12 i_pae 0.13 con 1.65 i_con 1.68 plddt 0.94 ptm 0.92 i_ptm 0.90 rg 2.14
# 104 models [0] recycles 1 hard 0 soft 1 temp 0.14 loss 3.62 helix 1.17 pae 0.12 i_pae 0.13 con 1.58 i_con 1.69 plddt 0.94 ptm 0.92 i_ptm 0.90 rg 2.09
# 105 models [2] recycles 1 hard 0 soft 1 temp 0.12 loss 3.66 helix 1.25 pae 0.12 i_pae 0.13 con 1.66 i_con 1.66 plddt 0.94 ptm 0.92 i_ptm 0.91 rg 2.15
# 106 models [2] recycles 1 hard 0 soft 1 temp 0.11 loss 3.90 helix 1.13 pae 0.13 i_pae 0.14 con 1.68 i_con 1.84 plddt 0.93 ptm 0.91 i_ptm 0.89 rg 2.12
# 107 models [2] recycles 1 hard 0 soft 1 temp 0.09 loss 5.43 helix 0.91 pae 0.32 i_pae 0.37 con 1.88 i_con 3.06 plddt 0.79 ptm 0.85 i_ptm 0.55 rg 1.87
# 108 models [4] recycles 1 hard 0 soft 1 temp 0.08 loss 3.46 helix 1.20 pae 0.11 i_pae 0.12 con 1.56 i_con 1.55 plddt 0.95 ptm 0.93 i_ptm 0.91 rg 2.15
# 109 models [1] recycles 1 hard 0 soft 1 temp 0.07 loss 3.54 helix 1.18 pae 0.11 i_pae 0.12 con 1.58 i_con 1.60 plddt 0.94 ptm 0.93 i_ptm 0.91 rg 2.18
# 110 models [3] recycles 1 hard 0 soft 1 temp 0.06 loss 3.19 helix 1.23 pae 0.10 i_pae 0.11 con 1.47 i_con 1.41 plddt 0.96 ptm 0.93 i_ptm 0.92 rg 2.04
# 111 models [3] recycles 1 hard 0 soft 1 temp 0.05 loss 3.23 helix 1.23 pae 0.10 i_pae 0.11 con 1.48 i_con 1.44 plddt 0.96 ptm 0.92 i_ptm 0.92 rg 2.07
# 112 models [0] recycles 1 hard 0 soft 1 temp 0.04 loss 3.41 helix 1.22 pae 0.11 i_pae 0.12 con 1.55 i_con 1.54 plddt 0.94 ptm 0.93 i_ptm 0.91 rg 2.09
# 113 models [0] recycles 1 hard 0 soft 1 temp 0.03 loss 3.42 helix 1.12 pae 0.11 i_pae 0.12 con 1.54 i_con 1.51 plddt 0.95 ptm 0.92 i_ptm 0.91 rg 2.11
# 114 models [2] recycles 1 hard 0 soft 1 temp 0.03 loss 3.77 helix 1.14 pae 0.12 i_pae 0.14 con 1.68 i_con 1.73 plddt 0.94 ptm 0.92 i_ptm 0.90 rg 2.12
# 115 models [2] recycles 1 hard 0 soft 1 temp 0.02 loss 3.52 helix 1.23 pae 0.11 i_pae 0.12 con 1.63 i_con 1.56 plddt 0.95 ptm 0.92 i_ptm 0.91 rg 2.13
# 116 models [3] recycles 1 hard 0 soft 1 temp 0.02 loss 3.33 helix 1.20 pae 0.11 i_pae 0.12 con 1.53 i_con 1.47 plddt 0.96 ptm 0.92 i_ptm 0.92 rg 2.10
# 117 models [0] recycles 1 hard 0 soft 1 temp 0.01 loss 3.56 helix 1.15 pae 0.11 i_pae 0.12 con 1.63 i_con 1.57 plddt 0.94 ptm 0.92 i_ptm 0.91 rg 2.15
# 118 models [0] recycles 1 hard 0 soft 1 temp 0.01 loss 3.35 helix 1.19 pae 0.11 i_pae 0.12 con 1.52 i_con 1.51 plddt 0.95 ptm 0.93 i_ptm 0.92 rg 2.07
# 119 models [2] recycles 1 hard 0 soft 1 temp 0.01 loss 3.73 helix 1.18 pae 0.12 i_pae 0.14 con 1.67 i_con 1.69 plddt 0.94 ptm 0.92 i_ptm 0.90 rg 2.20
# 120 models [0] recycles 1 hard 0 soft 1 temp 0.01 loss 3.36 helix 1.16 pae 0.11 i_pae 0.12 con 1.53 i_con 1.49 plddt 0.95 ptm 0.93 i_ptm 0.92 rg 2.07
# Softmax trajectory pLDDT good, continuing: 0.96
# Stage 3: One-hot Optimisation
# 121 models [2] recycles 1 hard 1 soft 1 temp 0.01 loss 3.42 helix 1.23 pae 0.11 i_pae 0.12 con 1.59 i_con 1.51 plddt 0.95 ptm 0.93 i_ptm 0.92 rg 2.12
# 122 models [1] recycles 1 hard 1 soft 1 temp 0.01 loss 3.26 helix 1.23 pae 0.10 i_pae 0.11 con 1.51 i_con 1.42 plddt 0.96 ptm 0.93 i_ptm 0.92 rg 2.12
# 123 models [2] recycles 1 hard 1 soft 1 temp 0.01 loss 3.43 helix 1.22 pae 0.11 i_pae 0.12 con 1.59 i_con 1.50 plddt 0.95 ptm 0.93 i_ptm 0.92 rg 2.12
# 124 models [4] recycles 1 hard 1 soft 1 temp 0.01 loss 3.35 helix 1.19 pae 0.10 i_pae 0.11 con 1.53 i_con 1.49 plddt 0.95 ptm 0.93 i_ptm 0.92 rg 2.07
# 125 models [4] recycles 1 hard 1 soft 1 temp 0.01 loss 3.42 helix 1.21 pae 0.10 i_pae 0.11 con 1.56 i_con 1.50 plddt 0.95 ptm 0.93 i_ptm 0.92 rg 2.22
# One-hot trajectory pLDDT good, continuing: 0.96
# Stage 4: PSSM Semigreedy Optimisation
# Running semigreedy optimization...
# 126 models [1] recycles 1 hard 1 soft 0 temp 1 loss 3.34 helix 1.20 pae 0.10 i_pae 0.11 con 1.53 i_con 1.47 plddt 0.95 ptm 0.93 i_ptm 0.92 rg 2.15
# 127 models [3] recycles 1 hard 1 soft 0 temp 1 loss 3.30 helix 1.19 pae 0.10 i_pae 0.11 con 1.53 i_con 1.42 plddt 0.96 ptm 0.93 i_ptm 0.92 rg 2.14
# 128 models [0] recycles 1 hard 1 soft 0 temp 1 loss 3.34 helix 1.09 pae 0.11 i_pae 0.12 con 1.47 i_con 1.48 plddt 0.94 ptm 0.93 i_ptm 0.92 rg 2.21
# 129 models [2] recycles 1 hard 1 soft 0 temp 1 loss 6.24 helix 0.81 pae 0.49 i_pae 0.58 con 1.87 i_con 3.78 plddt 0.65 ptm 0.79 i_ptm 0.26 rg 1.69
# 130 models [0] recycles 1 hard 1 soft 0 temp 1 loss 3.49 helix 1.04 pae 0.11 i_pae 0.12 con 1.53 i_con 1.56 plddt 0.93 ptm 0.93 i_ptm 0.91 rg 2.14
# 131 models [2] recycles 1 hard 1 soft 0 temp 1 loss 3.67 helix 1.06 pae 0.12 i_pae 0.13 con 1.60 i_con 1.65 plddt 0.93 ptm 0.92 i_ptm 0.91 rg 2.21
# 132 models [3] recycles 1 hard 1 soft 0 temp 1 loss 3.45 helix 1.07 pae 0.11 i_pae 0.12 con 1.52 i_con 1.54 plddt 0.94 ptm 0.93 i_ptm 0.92 rg 2.13
# 133 models [0] recycles 1 hard 1 soft 0 temp 1 loss 3.46 helix 1.02 pae 0.11 i_pae 0.12 con 1.52 i_con 1.54 plddt 0.94 ptm 0.93 i_ptm 0.91 rg 2.11
# 134 models [2] recycles 1 hard 1 soft 0 temp 1 loss 4.01 helix 1.00 pae 0.13 i_pae 0.15 con 1.70 i_con 1.86 plddt 0.91 ptm 0.92 i_ptm 0.89 rg 2.22
# 135 models [0] recycles 1 hard 1 soft 0 temp 1 loss 3.48 helix 1.08 pae 0.11 i_pae 0.12 con 1.58 i_con 1.52 plddt 0.94 ptm 0.93 i_ptm 0.91 rg 2.11
# 136 models [3] recycles 1 hard 1 soft 0 temp 1 loss 3.54 helix 1.09 pae 0.11 i_pae 0.12 con 1.60 i_con 1.56 plddt 0.94 ptm 0.93 i_ptm 0.91 rg 2.12
# 137 models [1] recycles 1 hard 1 soft 0 temp 1 loss 3.60 helix 1.07 pae 0.11 i_pae 0.12 con 1.64 i_con 1.56 plddt 0.94 ptm 0.93 i_ptm 0.91 rg 2.15
# 138 models [1] recycles 1 hard 1 soft 0 temp 1 loss 3.56 helix 1.08 pae 0.11 i_pae 0.12 con 1.62 i_con 1.55 plddt 0.94 ptm 0.93 i_ptm 0.92 rg 2.14
# 139 models [1] recycles 1 hard 1 soft 0 temp 1 loss 3.61 helix 1.09 pae 0.11 i_pae 0.12 con 1.68 i_con 1.55 plddt 0.94 ptm 0.93 i_ptm 0.92 rg 2.14
# 140 models [0] recycles 1 hard 1 soft 0 temp 1 loss 3.56 helix 1.03 pae 0.11 i_pae 0.12 con 1.65 i_con 1.51 plddt 0.94 ptm 0.93 i_ptm 0.92 rg 2.18
# Trajectory successful, final pLDDT: 0.96
# Starting trajectory took: 0 hours, 5 minutes, 35 seconds
#
# Fixing interface residues: B3,B6,B7,B10,B14,B17,B18,B21,B22,B23,B24,B28,B31,B32,B35,B36,B39,B40,B42,B43,B44,B46,B47,B48
# Base AF2 filters not passed for 6ARU_l48_s241256_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s241256_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s241256_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s241256_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s241256_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s241256_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s241256_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s241256_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s241256_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s241256_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s241256_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s241256_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s241256_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s241256_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s241256_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s241256_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s241256_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s241256_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s241256_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s241256_mpnn1, skipping interface scoring
# No accepted MPNN designs found for this trajectory.
# Design and validation of trajectory 6ARU_l48_s241256 took: 0 hours, 1 minutes, 9 seconds
# Starting trajectory: 6ARU_l48_s723207
# Stage 1: Test Logits
# 1 models [2] recycles 1 hard 0 soft 0.02 temp 1 loss 10.75 helix 1.40 pae 0.74 i_pae 0.76 con 4.49 i_con 4.26 plddt 0.28 ptm 0.77 i_ptm 0.18 rg 6.46
# 2 models [1] recycles 1 hard 0 soft 0.04 temp 1 loss 9.82 helix 1.05 pae 0.68 i_pae 0.71 con 4.69 i_con 4.23 plddt 0.40 ptm 0.79 i_ptm 0.22 rg 2.57
# 3 models [4] recycles 1 hard 0 soft 0.05 temp 1 loss 8.30 helix 1.38 pae 0.68 i_pae 0.70 con 4.33 i_con 4.01 plddt 0.29 ptm 0.78 i_ptm 0.22 rg -0.24
# 4 models [4] recycles 1 hard 0 soft 0.07 temp 1 loss 8.98 helix 1.23 pae 0.64 i_pae 0.66 con 4.48 i_con 3.89 plddt 0.38 ptm 0.79 i_ptm 0.26 rg 1.84
# 5 models [1] recycles 1 hard 0 soft 0.09 temp 1 loss 8.82 helix 1.39 pae 0.69 i_pae 0.72 con 4.23 i_con 4.20 plddt 0.31 ptm 0.78 i_ptm 0.20 rg 1.15
# 6 models [1] recycles 1 hard 0 soft 0.11 temp 1 loss 9.06 helix 1.36 pae 0.73 i_pae 0.77 con 4.24 i_con 4.38 plddt 0.33 ptm 0.78 i_ptm 0.17 rg 1.23
# 7 models [0] recycles 1 hard 0 soft 0.13 temp 1 loss 8.14 helix 1.37 pae 0.66 i_pae 0.69 con 4.11 i_con 4.06 plddt 0.30 ptm 0.78 i_ptm 0.22 rg -0.16
# 8 models [0] recycles 1 hard 0 soft 0.14 temp 1 loss 7.89 helix 1.13 pae 0.63 i_pae 0.66 con 3.94 i_con 3.99 plddt 0.36 ptm 0.78 i_ptm 0.24 rg -0.38
# 9 models [0] recycles 1 hard 0 soft 0.16 temp 1 loss 7.60 helix 1.03 pae 0.63 i_pae 0.68 con 3.63 i_con 4.07 plddt 0.40 ptm 0.78 i_ptm 0.23 rg -0.73
# 10 models [3] recycles 1 hard 0 soft 0.18 temp 1 loss 7.65 helix 1.12 pae 0.64 i_pae 0.69 con 3.62 i_con 4.11 plddt 0.39 ptm 0.78 i_ptm 0.24 rg -0.55
# 11 models [4] recycles 1 hard 0 soft 0.20 temp 1 loss 7.37 helix 1.15 pae 0.63 i_pae 0.69 con 3.45 i_con 4.05 plddt 0.42 ptm 0.78 i_ptm 0.22 rg -0.68
# 12 models [3] recycles 1 hard 0 soft 0.22 temp 1 loss 6.55 helix 1.33 pae 0.53 i_pae 0.60 con 2.85 i_con 3.86 plddt 0.56 ptm 0.79 i_ptm 0.29 rg -0.39
# 13 models [3] recycles 1 hard 0 soft 0.23 temp 1 loss 7.54 helix 1.06 pae 0.61 i_pae 0.67 con 3.56 i_con 4.04 plddt 0.44 ptm 0.78 i_ptm 0.24 rg -0.51
# 14 models [1] recycles 1 hard 0 soft 0.25 temp 1 loss 7.00 helix 1.25 pae 0.60 i_pae 0.67 con 3.06 i_con 4.07 plddt 0.47 ptm 0.78 i_ptm 0.22 rg -0.50
# 15 models [0] recycles 1 hard 0 soft 0.27 temp 1 loss 5.92 helix 1.72 pae 0.53 i_pae 0.62 con 2.33 i_con 3.88 plddt 0.58 ptm 0.78 i_ptm 0.26 rg -0.45
# 16 models [3] recycles 1 hard 0 soft 0.29 temp 1 loss 7.03 helix 1.25 pae 0.61 i_pae 0.69 con 3.04 i_con 4.16 plddt 0.49 ptm 0.78 i_ptm 0.23 rg -0.66
# 17 models [4] recycles 1 hard 0 soft 0.31 temp 1 loss 6.38 helix 1.34 pae 0.55 i_pae 0.63 con 2.68 i_con 3.90 plddt 0.54 ptm 0.79 i_ptm 0.26 rg -0.53
# 18 models [2] recycles 1 hard 0 soft 0.32 temp 1 loss 6.59 helix 1.22 pae 0.56 i_pae 0.63 con 2.88 i_con 3.89 plddt 0.51 ptm 0.79 i_ptm 0.27 rg -0.59
# 19 models [0] recycles 1 hard 0 soft 0.34 temp 1 loss 6.19 helix 1.56 pae 0.58 i_pae 0.68 con 2.26 i_con 4.16 plddt 0.58 ptm 0.78 i_ptm 0.21 rg -0.49
# 20 models [4] recycles 1 hard 0 soft 0.36 temp 1 loss 6.36 helix 1.53 pae 0.59 i_pae 0.69 con 2.45 i_con 4.13 plddt 0.59 ptm 0.78 i_ptm 0.21 rg -0.46
# 21 models [4] recycles 1 hard 0 soft 0.38 temp 1 loss 5.99 helix 1.55 pae 0.54 i_pae 0.63 con 2.30 i_con 3.92 plddt 0.63 ptm 0.79 i_ptm 0.26 rg -0.39
# 22 models [3] recycles 1 hard 0 soft 0.40 temp 1 loss 5.64 helix 1.63 pae 0.50 i_pae 0.59 con 2.09 i_con 3.80 plddt 0.71 ptm 0.79 i_ptm 0.31 rg -0.25
# 23 models [4] recycles 1 hard 0 soft 0.41 temp 1 loss 5.97 helix 1.61 pae 0.56 i_pae 0.66 con 2.18 i_con 4.03 plddt 0.66 ptm 0.78 i_ptm 0.23 rg -0.38
# 24 models [2] recycles 1 hard 0 soft 0.43 temp 1 loss 5.43 helix 1.65 pae 0.46 i_pae 0.54 con 2.04 i_con 3.65 plddt 0.74 ptm 0.80 i_ptm 0.33 rg -0.22
# 25 models [4] recycles 1 hard 0 soft 0.45 temp 1 loss 5.57 helix 1.60 pae 0.50 i_pae 0.59 con 2.01 i_con 3.79 plddt 0.73 ptm 0.79 i_ptm 0.29 rg -0.20
# 26 models [1] recycles 1 hard 0 soft 0.47 temp 1 loss 5.18 helix 1.63 pae 0.39 i_pae 0.46 con 2.03 i_con 3.42 plddt 0.77 ptm 0.83 i_ptm 0.44 rg -0.12
# 27 models [0] recycles 1 hard 0 soft 0.49 temp 1 loss 4.70 helix 1.71 pae 0.34 i_pae 0.40 con 1.87 i_con 3.17 plddt 0.80 ptm 0.84 i_ptm 0.52 rg -0.14
# 28 models [0] recycles 1 hard 0 soft 0.50 temp 1 loss 4.65 helix 1.65 pae 0.33 i_pae 0.38 con 1.84 i_con 3.11 plddt 0.81 ptm 0.84 i_ptm 0.54 rg -0.06
# 29 models [2] recycles 1 hard 0 soft 0.52 temp 1 loss 4.52 helix 1.57 pae 0.28 i_pae 0.32 con 2.00 i_con 2.82 plddt 0.84 ptm 0.87 i_ptm 0.65 rg -0.02
# 30 models [2] recycles 1 hard 0 soft 0.54 temp 1 loss 4.41 helix 1.64 pae 0.28 i_pae 0.32 con 1.96 i_con 2.77 plddt 0.84 ptm 0.86 i_ptm 0.67 rg -0.01
# 31 models [3] recycles 1 hard 0 soft 0.56 temp 1 loss 4.64 helix 1.61 pae 0.30 i_pae 0.35 con 1.97 i_con 2.98 plddt 0.83 ptm 0.85 i_ptm 0.61 rg -0.06
# 32 models [4] recycles 1 hard 0 soft 0.58 temp 1 loss 4.62 helix 1.72 pae 0.34 i_pae 0.39 con 1.84 i_con 3.10 plddt 0.83 ptm 0.84 i_ptm 0.53 rg -0.04
# 33 models [3] recycles 1 hard 0 soft 0.59 temp 1 loss 3.92 helix 1.75 pae 0.20 i_pae 0.22 con 1.91 i_con 2.37 plddt 0.88 ptm 0.90 i_ptm 0.80 rg 0.13
# 34 models [0] recycles 1 hard 0 soft 0.61 temp 1 loss 3.90 helix 1.76 pae 0.20 i_pae 0.22 con 1.86 i_con 2.42 plddt 0.88 ptm 0.90 i_ptm 0.79 rg 0.08
# 35 models [2] recycles 1 hard 0 soft 0.63 temp 1 loss 3.79 helix 1.70 pae 0.19 i_pae 0.22 con 1.86 i_con 2.31 plddt 0.89 ptm 0.90 i_ptm 0.81 rg 0.03
# 36 models [0] recycles 1 hard 0 soft 0.65 temp 1 loss 4.19 helix 1.80 pae 0.24 i_pae 0.25 con 2.04 i_con 2.54 plddt 0.84 ptm 0.89 i_ptm 0.76 rg 0.01
# 37 models [4] recycles 1 hard 0 soft 0.67 temp 1 loss 3.95 helix 1.74 pae 0.20 i_pae 0.23 con 1.91 i_con 2.40 plddt 0.87 ptm 0.90 i_ptm 0.79 rg 0.10
# 38 models [4] recycles 1 hard 0 soft 0.68 temp 1 loss 3.74 helix 1.92 pae 0.19 i_pae 0.22 con 1.79 i_con 2.37 plddt 0.89 ptm 0.90 i_ptm 0.80 rg 0.12
# 39 models [3] recycles 1 hard 0 soft 0.70 temp 1 loss 4.37 helix 1.90 pae 0.28 i_pae 0.32 con 1.84 i_con 2.92 plddt 0.84 ptm 0.86 i_ptm 0.64 rg -0.00
# 40 models [1] recycles 1 hard 0 soft 0.72 temp 1 loss 4.24 helix 1.74 pae 0.24 i_pae 0.27 con 1.95 i_con 2.66 plddt 0.84 ptm 0.88 i_ptm 0.71 rg 0.01
# 41 models [2] recycles 1 hard 0 soft 0.74 temp 1 loss 4.90 helix 1.44 pae 0.29 i_pae 0.32 con 2.29 i_con 2.86 plddt 0.80 ptm 0.86 i_ptm 0.66 rg -0.02
# 42 models [0] recycles 1 hard 0 soft 0.76 temp 1 loss 4.15 helix 1.81 pae 0.24 i_pae 0.27 con 1.90 i_con 2.64 plddt 0.85 ptm 0.88 i_ptm 0.71 rg 0.02
# 43 models [3] recycles 1 hard 0 soft 0.77 temp 1 loss 4.06 helix 1.68 pae 0.21 i_pae 0.24 con 1.92 i_con 2.48 plddt 0.87 ptm 0.89 i_ptm 0.76 rg 0.11
# 44 models [3] recycles 1 hard 0 soft 0.79 temp 1 loss 3.75 helix 1.84 pae 0.18 i_pae 0.20 con 1.86 i_con 2.27 plddt 0.89 ptm 0.90 i_ptm 0.82 rg 0.20
# 45 models [1] recycles 1 hard 0 soft 0.81 temp 1 loss 5.72 helix 1.37 pae 0.45 i_pae 0.52 con 2.28 i_con 3.62 plddt 0.67 ptm 0.82 i_ptm 0.38 rg -0.19
# 46 models [2] recycles 1 hard 0 soft 0.83 temp 1 loss 3.82 helix 1.77 pae 0.19 i_pae 0.22 con 1.88 i_con 2.31 plddt 0.89 ptm 0.89 i_ptm 0.80 rg 0.14
# 47 models [0] recycles 1 hard 0 soft 0.85 temp 1 loss 6.09 helix 1.52 pae 0.50 i_pae 0.58 con 2.43 i_con 3.82 plddt 0.59 ptm 0.79 i_ptm 0.30 rg -0.13
# 48 models [2] recycles 1 hard 0 soft 0.86 temp 1 loss 5.51 helix 1.54 pae 0.43 i_pae 0.50 con 2.28 i_con 3.39 plddt 0.72 ptm 0.82 i_ptm 0.40 rg 0.06
# 49 models [1] recycles 1 hard 0 soft 0.88 temp 1 loss 6.50 helix 1.18 pae 0.51 i_pae 0.56 con 2.76 i_con 3.84 plddt 0.58 ptm 0.81 i_ptm 0.34 rg -0.24
# 50 models [4] recycles 1 hard 0 soft 0.90 temp 1 loss 4.49 helix 1.76 pae 0.30 i_pae 0.34 con 1.92 i_con 2.91 plddt 0.83 ptm 0.86 i_ptm 0.60 rg -0.02
# Initial trajectory pLDDT good, continuing: 0.89
# Stage 1: Additional Logits Optimisation
# 51 models [4] recycles 1 hard 0 soft 0.04 temp 1 loss 6.91 helix 1.07 pae 0.56 i_pae 0.62 con 3.01 i_con 3.92 plddt 0.52 ptm 0.79 i_ptm 0.28 rg -0.24
# 52 models [3] recycles 1 hard 0 soft 0.08 temp 1 loss 4.24 helix 1.61 pae 0.21 i_pae 0.23 con 2.08 i_con 2.46 plddt 0.86 ptm 0.89 i_ptm 0.78 rg 0.13
# 53 models [3] recycles 1 hard 0 soft 0.12 temp 1 loss 3.49 helix 1.85 pae 0.16 i_pae 0.18 con 1.73 i_con 2.18 plddt 0.91 ptm 0.91 i_ptm 0.84 rg 0.12
# 54 models [2] recycles 1 hard 0 soft 0.16 temp 1 loss 4.20 helix 1.75 pae 0.26 i_pae 0.30 con 1.81 i_con 2.75 plddt 0.86 ptm 0.86 i_ptm 0.64 rg -0.00
# 55 models [3] recycles 1 hard 0 soft 0.20 temp 1 loss 3.86 helix 1.79 pae 0.20 i_pae 0.22 con 1.85 i_con 2.39 plddt 0.89 ptm 0.90 i_ptm 0.78 rg 0.11
# 56 models [3] recycles 1 hard 0 soft 0.24 temp 1 loss 3.42 helix 1.97 pae 0.16 i_pae 0.18 con 1.77 i_con 2.11 plddt 0.91 ptm 0.91 i_ptm 0.86 rg 0.12
# 57 models [2] recycles 1 hard 0 soft 0.28 temp 1 loss 3.32 helix 2.03 pae 0.16 i_pae 0.17 con 1.72 i_con 2.07 plddt 0.93 ptm 0.91 i_ptm 0.87 rg 0.15
# 58 models [2] recycles 1 hard 0 soft 0.32 temp 1 loss 3.56 helix 1.93 pae 0.18 i_pae 0.20 con 1.74 i_con 2.26 plddt 0.91 ptm 0.90 i_ptm 0.83 rg 0.09
# 59 models [3] recycles 1 hard 0 soft 0.36 temp 1 loss 3.28 helix 2.06 pae 0.15 i_pae 0.17 con 1.69 i_con 2.07 plddt 0.92 ptm 0.91 i_ptm 0.86 rg 0.12
# 60 models [0] recycles 1 hard 0 soft 0.40 temp 1 loss 3.70 helix 1.96 pae 0.19 i_pae 0.22 con 1.74 i_con 2.42 plddt 0.89 ptm 0.89 i_ptm 0.78 rg 0.02
# 61 models [2] recycles 1 hard 0 soft 0.44 temp 1 loss 3.94 helix 1.85 pae 0.22 i_pae 0.26 con 1.80 i_con 2.54 plddt 0.88 ptm 0.88 i_ptm 0.74 rg 0.05
# 62 models [3] recycles 1 hard 0 soft 0.48 temp 1 loss 3.54 helix 2.06 pae 0.18 i_pae 0.20 con 1.70 i_con 2.33 plddt 0.90 ptm 0.90 i_ptm 0.79 rg 0.07
# 63 models [1] recycles 1 hard 0 soft 0.52 temp 1 loss 3.91 helix 1.93 pae 0.24 i_pae 0.28 con 1.69 i_con 2.67 plddt 0.88 ptm 0.87 i_ptm 0.68 rg -0.07
# 64 models [4] recycles 1 hard 0 soft 0.56 temp 1 loss 3.52 helix 2.05 pae 0.19 i_pae 0.22 con 1.66 i_con 2.37 plddt 0.91 ptm 0.89 i_ptm 0.80 rg -0.04
# 65 models [0] recycles 1 hard 0 soft 0.60 temp 1 loss 3.38 helix 2.13 pae 0.17 i_pae 0.19 con 1.71 i_con 2.20 plddt 0.90 ptm 0.91 i_ptm 0.84 rg 0.01
# 66 models [1] recycles 1 hard 0 soft 0.64 temp 1 loss 3.69 helix 2.01 pae 0.18 i_pae 0.20 con 1.79 i_con 2.37 plddt 0.89 ptm 0.90 i_ptm 0.81 rg 0.04
# 67 models [0] recycles 1 hard 0 soft 0.68 temp 1 loss 3.55 helix 2.03 pae 0.17 i_pae 0.19 con 1.82 i_con 2.18 plddt 0.90 ptm 0.91 i_ptm 0.84 rg 0.16
# 68 models [4] recycles 1 hard 0 soft 0.72 temp 1 loss 3.50 helix 2.17 pae 0.18 i_pae 0.21 con 1.69 i_con 2.32 plddt 0.91 ptm 0.90 i_ptm 0.80 rg 0.08
# 69 models [0] recycles 1 hard 0 soft 0.76 temp 1 loss 3.29 helix 2.17 pae 0.16 i_pae 0.18 con 1.74 i_con 2.06 plddt 0.91 ptm 0.91 i_ptm 0.86 rg 0.11
# 70 models [0] recycles 1 hard 0 soft 0.80 temp 1 loss 6.95 helix 1.56 pae 0.60 i_pae 0.66 con 3.04 i_con 4.09 plddt 0.50 ptm 0.78 i_ptm 0.25 rg -0.35
# 71 models [1] recycles 1 hard 0 soft 0.84 temp 1 loss 3.40 helix 2.05 pae 0.17 i_pae 0.19 con 1.76 i_con 2.13 plddt 0.90 ptm 0.91 i_ptm 0.85 rg 0.09
# 72 models [2] recycles 1 hard 0 soft 0.88 temp 1 loss 3.90 helix 1.82 pae 0.21 i_pae 0.23 con 1.95 i_con 2.36 plddt 0.88 ptm 0.89 i_ptm 0.80 rg 0.02
# 73 models [2] recycles 1 hard 0 soft 0.92 temp 1 loss 7.54 helix 1.48 pae 0.64 i_pae 0.69 con 3.46 i_con 4.05 plddt 0.41 ptm 0.78 i_ptm 0.25 rg 0.17
# 74 models [0] recycles 1 hard 0 soft 0.96 temp 1 loss 7.01 helix 1.52 pae 0.59 i_pae 0.65 con 2.78 i_con 4.03 plddt 0.51 ptm 0.78 i_ptm 0.24 rg 0.86
# 75 models [2] recycles 1 hard 0 soft 1 temp 1 loss 7.01 helix 1.14 pae 0.57 i_pae 0.63 con 3.18 i_con 3.93 plddt 0.50 ptm 0.79 i_ptm 0.27 rg -0.43
# Optimised logit trajectory pLDDT: 0.92
# Stage 2: Softmax Optimisation
# 76 models [2] recycles 1 hard 0 soft 1 temp 0.96 loss 7.51 helix 1.12 pae 0.59 i_pae 0.63 con 3.63 i_con 3.88 plddt 0.44 ptm 0.79 i_ptm 0.28 rg -0.19
# 77 models [2] recycles 1 hard 0 soft 1 temp 0.91 loss 6.22 helix 1.35 pae 0.50 i_pae 0.57 con 2.66 i_con 3.75 plddt 0.62 ptm 0.80 i_ptm 0.33 rg -0.36
# 78 models [4] recycles 1 hard 0 soft 1 temp 0.87 loss 5.74 helix 1.58 pae 0.49 i_pae 0.57 con 2.28 i_con 3.68 plddt 0.67 ptm 0.80 i_ptm 0.32 rg -0.24
# 79 models [3] recycles 1 hard 0 soft 1 temp 0.83 loss 7.98 helix 1.22 pae 0.58 i_pae 0.61 con 3.96 i_con 3.78 plddt 0.40 ptm 0.80 i_ptm 0.32 rg 0.73
# 80 models [0] recycles 1 hard 0 soft 1 temp 0.79 loss 4.35 helix 1.75 pae 0.24 i_pae 0.26 con 2.08 i_con 2.61 plddt 0.83 ptm 0.88 i_ptm 0.72 rg 0.10
# 81 models [4] recycles 1 hard 0 soft 1 temp 0.75 loss 4.42 helix 1.65 pae 0.25 i_pae 0.27 con 2.15 i_con 2.64 plddt 0.82 ptm 0.88 i_ptm 0.73 rg -0.10
# 82 models [0] recycles 1 hard 0 soft 1 temp 0.72 loss 4.41 helix 1.81 pae 0.24 i_pae 0.27 con 2.09 i_con 2.66 plddt 0.83 ptm 0.88 i_ptm 0.71 rg 0.13
# 83 models [4] recycles 1 hard 0 soft 1 temp 0.68 loss 5.03 helix 1.64 pae 0.36 i_pae 0.41 con 2.13 i_con 3.18 plddt 0.77 ptm 0.84 i_ptm 0.53 rg -0.05
# 84 models [4] recycles 1 hard 0 soft 1 temp 0.64 loss 4.13 helix 1.77 pae 0.21 i_pae 0.23 con 2.02 i_con 2.43 plddt 0.87 ptm 0.90 i_ptm 0.79 rg 0.30
# 85 models [0] recycles 1 hard 0 soft 1 temp 0.61 loss 4.03 helix 1.89 pae 0.21 i_pae 0.23 con 1.93 i_con 2.45 plddt 0.87 ptm 0.89 i_ptm 0.76 rg 0.28
# 86 models [1] recycles 1 hard 0 soft 1 temp 0.58 loss 3.88 helix 1.77 pae 0.20 i_pae 0.22 con 1.88 i_con 2.41 plddt 0.87 ptm 0.90 i_ptm 0.78 rg -0.00
# 87 models [2] recycles 1 hard 0 soft 1 temp 0.54 loss 3.98 helix 1.83 pae 0.20 i_pae 0.23 con 2.00 i_con 2.37 plddt 0.87 ptm 0.90 i_ptm 0.79 rg 0.09
# 88 models [4] recycles 1 hard 0 soft 1 temp 0.51 loss 4.61 helix 1.53 pae 0.26 i_pae 0.29 con 2.20 i_con 2.72 plddt 0.82 ptm 0.88 i_ptm 0.71 rg -0.04
# 89 models [4] recycles 1 hard 0 soft 1 temp 0.48 loss 3.98 helix 1.79 pae 0.21 i_pae 0.23 con 1.93 i_con 2.49 plddt 0.87 ptm 0.89 i_ptm 0.78 rg -0.08
# 90 models [3] recycles 1 hard 0 soft 1 temp 0.45 loss 3.76 helix 1.81 pae 0.18 i_pae 0.20 con 1.92 i_con 2.23 plddt 0.88 ptm 0.90 i_ptm 0.82 rg 0.15
# 91 models [4] recycles 1 hard 0 soft 1 temp 0.42 loss 3.89 helix 1.83 pae 0.21 i_pae 0.24 con 1.84 i_con 2.51 plddt 0.88 ptm 0.89 i_ptm 0.77 rg -0.13
# 92 models [1] recycles 1 hard 0 soft 1 temp 0.39 loss 7.47 helix 1.22 pae 0.54 i_pae 0.57 con 3.64 i_con 3.70 plddt 0.45 ptm 0.81 i_ptm 0.35 rg 0.44
# 93 models [4] recycles 1 hard 0 soft 1 temp 0.37 loss 5.45 helix 1.35 pae 0.39 i_pae 0.45 con 2.34 i_con 3.34 plddt 0.70 ptm 0.83 i_ptm 0.47 rg -0.29
# 94 models [3] recycles 1 hard 0 soft 1 temp 0.34 loss 3.75 helix 1.87 pae 0.18 i_pae 0.20 con 1.96 i_con 2.23 plddt 0.88 ptm 0.91 i_ptm 0.83 rg 0.05
# 95 models [0] recycles 1 hard 0 soft 1 temp 0.32 loss 5.18 helix 1.55 pae 0.35 i_pae 0.40 con 2.23 i_con 3.22 plddt 0.77 ptm 0.84 i_ptm 0.52 rg -0.11
# 96 models [1] recycles 1 hard 0 soft 1 temp 0.29 loss 4.61 helix 1.69 pae 0.30 i_pae 0.34 con 1.95 i_con 3.01 plddt 0.80 ptm 0.86 i_ptm 0.58 rg -0.11
# 97 models [4] recycles 1 hard 0 soft 1 temp 0.27 loss 3.98 helix 1.82 pae 0.21 i_pae 0.23 con 1.88 i_con 2.51 plddt 0.88 ptm 0.89 i_ptm 0.76 rg 0.02
# 98 models [4] recycles 1 hard 0 soft 1 temp 0.25 loss 7.61 helix 1.16 pae 0.59 i_pae 0.63 con 3.67 i_con 3.88 plddt 0.43 ptm 0.80 i_ptm 0.28 rg 0.07
# 99 models [3] recycles 1 hard 0 soft 1 temp 0.23 loss 6.76 helix 1.21 pae 0.54 i_pae 0.59 con 3.06 i_con 3.76 plddt 0.53 ptm 0.80 i_ptm 0.34 rg -0.16
# 100 models [1] recycles 1 hard 0 soft 1 temp 0.21 loss 5.02 helix 1.67 pae 0.36 i_pae 0.42 con 2.09 i_con 3.25 plddt 0.77 ptm 0.84 i_ptm 0.50 rg -0.20
# 101 models [2] recycles 1 hard 0 soft 1 temp 0.19 loss 4.58 helix 1.59 pae 0.24 i_pae 0.27 con 2.31 i_con 2.62 plddt 0.82 ptm 0.88 i_ptm 0.74 rg -0.06
# 102 models [1] recycles 1 hard 0 soft 1 temp 0.17 loss 4.14 helix 1.84 pae 0.23 i_pae 0.26 con 1.93 i_con 2.62 plddt 0.85 ptm 0.89 i_ptm 0.73 rg -0.03
# 103 models [0] recycles 1 hard 0 soft 1 temp 0.15 loss 3.73 helix 1.93 pae 0.18 i_pae 0.20 con 1.91 i_con 2.28 plddt 0.89 ptm 0.90 i_ptm 0.81 rg -0.00
# 104 models [0] recycles 1 hard 0 soft 1 temp 0.14 loss 4.42 helix 1.66 pae 0.24 i_pae 0.28 con 2.05 i_con 2.74 plddt 0.84 ptm 0.87 i_ptm 0.70 rg -0.09
# 105 models [4] recycles 1 hard 0 soft 1 temp 0.12 loss 4.75 helix 1.70 pae 0.31 i_pae 0.35 con 2.06 i_con 3.04 plddt 0.80 ptm 0.86 i_ptm 0.59 rg -0.11
# 106 models [4] recycles 1 hard 0 soft 1 temp 0.11 loss 4.56 helix 1.69 pae 0.27 i_pae 0.31 con 2.09 i_con 2.84 plddt 0.82 ptm 0.87 i_ptm 0.66 rg -0.13
# 107 models [4] recycles 1 hard 0 soft 1 temp 0.09 loss 4.09 helix 1.80 pae 0.21 i_pae 0.23 con 1.98 i_con 2.51 plddt 0.86 ptm 0.90 i_ptm 0.77 rg 0.02
# 108 models [0] recycles 1 hard 0 soft 1 temp 0.08 loss 3.72 helix 2.00 pae 0.18 i_pae 0.20 con 1.86 i_con 2.33 plddt 0.89 ptm 0.90 i_ptm 0.82 rg 0.10
# 109 models [4] recycles 1 hard 0 soft 1 temp 0.07 loss 4.16 helix 1.82 pae 0.23 i_pae 0.27 con 1.90 i_con 2.69 plddt 0.85 ptm 0.88 i_ptm 0.71 rg -0.12
# 110 models [0] recycles 1 hard 0 soft 1 temp 0.06 loss 3.67 helix 1.93 pae 0.18 i_pae 0.20 con 1.85 i_con 2.28 plddt 0.89 ptm 0.90 i_ptm 0.82 rg 0.03
# 111 models [0] recycles 1 hard 0 soft 1 temp 0.05 loss 6.23 helix 1.67 pae 0.59 i_pae 0.68 con 2.38 i_con 4.16 plddt 0.59 ptm 0.78 i_ptm 0.21 rg -0.63
# 112 models [0] recycles 1 hard 0 soft 1 temp 0.04 loss 4.64 helix 1.70 pae 0.25 i_pae 0.28 con 2.24 i_con 2.72 plddt 0.80 ptm 0.88 i_ptm 0.71 rg 0.08
# 113 models [4] recycles 1 hard 0 soft 1 temp 0.03 loss 5.00 helix 1.59 pae 0.31 i_pae 0.35 con 2.34 i_con 2.99 plddt 0.78 ptm 0.86 i_ptm 0.61 rg -0.17
# 114 models [0] recycles 1 hard 0 soft 1 temp 0.03 loss 3.68 helix 1.97 pae 0.18 i_pae 0.20 con 1.87 i_con 2.28 plddt 0.88 ptm 0.90 i_ptm 0.82 rg 0.01
# 115 models [2] recycles 1 hard 0 soft 1 temp 0.02 loss 6.80 helix 1.28 pae 0.46 i_pae 0.49 con 3.42 i_con 3.36 plddt 0.59 ptm 0.83 i_ptm 0.47 rg 0.36
# 116 models [4] recycles 1 hard 0 soft 1 temp 0.02 loss 7.11 helix 1.16 pae 0.52 i_pae 0.56 con 3.46 i_con 3.64 plddt 0.51 ptm 0.81 i_ptm 0.37 rg 0.06
# 117 models [3] recycles 1 hard 0 soft 1 temp 0.01 loss 6.29 helix 1.35 pae 0.40 i_pae 0.42 con 3.35 i_con 3.08 plddt 0.62 ptm 0.85 i_ptm 0.63 rg 0.02
# 118 models [4] recycles 1 hard 0 soft 1 temp 0.01 loss 4.25 helix 1.84 pae 0.25 i_pae 0.28 con 1.94 i_con 2.75 plddt 0.86 ptm 0.88 i_ptm 0.70 rg -0.10
# 119 models [4] recycles 1 hard 0 soft 1 temp 0.01 loss 4.65 helix 1.62 pae 0.28 i_pae 0.32 con 2.14 i_con 2.87 plddt 0.81 ptm 0.87 i_ptm 0.65 rg -0.17
# 120 models [2] recycles 1 hard 0 soft 1 temp 0.01 loss 7.07 helix 1.21 pae 0.51 i_pae 0.55 con 3.49 i_con 3.56 plddt 0.55 ptm 0.81 i_ptm 0.39 rg 0.13
# Softmax trajectory pLDDT good, continuing: 0.89
# Stage 3: One-hot Optimisation
# 121 models [0] recycles 1 hard 1 soft 1 temp 0.01 loss 3.94 helix 1.88 pae 0.17 i_pae 0.19 con 2.01 i_con 2.31 plddt 0.86 ptm 0.91 i_ptm 0.83 rg 0.23
# 122 models [1] recycles 1 hard 1 soft 1 temp 0.01 loss 6.17 helix 1.70 pae 0.58 i_pae 0.68 con 2.30 i_con 4.14 plddt 0.54 ptm 0.79 i_ptm 0.22 rg -0.48
# 123 models [4] recycles 1 hard 1 soft 1 temp 0.01 loss 4.66 helix 1.56 pae 0.26 i_pae 0.29 con 2.27 i_con 2.72 plddt 0.76 ptm 0.88 i_ptm 0.70 rg -0.11
# 124 models [2] recycles 1 hard 1 soft 1 temp 0.01 loss 6.44 helix 1.34 pae 0.40 i_pae 0.42 con 3.34 i_con 3.05 plddt 0.59 ptm 0.86 i_ptm 0.59 rg 0.65
# 125 models [0] recycles 1 hard 1 soft 1 temp 0.01 loss 4.27 helix 1.71 pae 0.20 i_pae 0.22 con 2.18 i_con 2.41 plddt 0.83 ptm 0.90 i_ptm 0.81 rg 0.20
# One-hot trajectory pLDDT good, continuing: 0.86
# Stage 4: PSSM Semigreedy Optimisation
# Running semigreedy optimization...
# 126 models [3] recycles 1 hard 1 soft 0 temp 1 loss 4.07 helix 1.74 pae 0.20 i_pae 0.21 con 2.13 i_con 2.29 plddt 0.84 ptm 0.91 i_ptm 0.81 rg 0.17
# 127 models [1] recycles 1 hard 1 soft 0 temp 1 loss 5.93 helix 1.73 pae 0.57 i_pae 0.67 con 2.12 i_con 4.11 plddt 0.55 ptm 0.79 i_ptm 0.22 rg -0.51
# 128 models [0] recycles 1 hard 1 soft 0 temp 1 loss 5.99 helix 1.73 pae 0.58 i_pae 0.68 con 2.11 i_con 4.15 plddt 0.51 ptm 0.78 i_ptm 0.21 rg -0.47
# 129 models [3] recycles 1 hard 1 soft 0 temp 1 loss 4.82 helix 1.53 pae 0.25 i_pae 0.27 con 2.36 i_con 2.72 plddt 0.78 ptm 0.89 i_ptm 0.73 rg 0.09
# 130 models [0] recycles 1 hard 1 soft 0 temp 1 loss 7.14 helix 1.22 pae 0.63 i_pae 0.69 con 3.09 i_con 4.18 plddt 0.39 ptm 0.78 i_ptm 0.22 rg -0.60
# 131 models [0] recycles 1 hard 1 soft 0 temp 1 loss 7.25 helix 1.21 pae 0.62 i_pae 0.68 con 3.16 i_con 4.16 plddt 0.37 ptm 0.78 i_ptm 0.23 rg -0.45
# 132 models [3] recycles 1 hard 1 soft 0 temp 1 loss 5.75 helix 1.37 pae 0.44 i_pae 0.50 con 2.37 i_con 3.59 plddt 0.63 ptm 0.82 i_ptm 0.41 rg -0.30
# 133 models [0] recycles 1 hard 1 soft 0 temp 1 loss 7.18 helix 1.20 pae 0.63 i_pae 0.69 con 3.12 i_con 4.17 plddt 0.38 ptm 0.78 i_ptm 0.22 rg -0.56
# 134 models [1] recycles 1 hard 1 soft 0 temp 1 loss 6.46 helix 1.32 pae 0.59 i_pae 0.66 con 2.57 i_con 4.09 plddt 0.47 ptm 0.79 i_ptm 0.24 rg -0.64
# 135 models [0] recycles 1 hard 1 soft 0 temp 1 loss 6.42 helix 1.31 pae 0.59 i_pae 0.68 con 2.46 i_con 4.16 plddt 0.49 ptm 0.78 i_ptm 0.22 rg -0.65
# 136 models [4] recycles 1 hard 1 soft 0 temp 1 loss 7.39 helix 1.04 pae 0.61 i_pae 0.67 con 3.38 i_con 4.06 plddt 0.36 ptm 0.79 i_ptm 0.24 rg -0.51
# 137 models [4] recycles 1 hard 1 soft 0 temp 1 loss 7.91 helix 1.14 pae 0.64 i_pae 0.68 con 3.86 i_con 4.06 plddt 0.29 ptm 0.79 i_ptm 0.24 rg -0.32
# 138 models [4] recycles 1 hard 1 soft 0 temp 1 loss 7.90 helix 1.16 pae 0.63 i_pae 0.67 con 3.83 i_con 4.02 plddt 0.29 ptm 0.79 i_ptm 0.25 rg -0.12
# 139 models [3] recycles 1 hard 1 soft 0 temp 1 loss 8.24 helix 1.15 pae 0.64 i_pae 0.68 con 3.83 i_con 4.13 plddt 0.30 ptm 0.79 i_ptm 0.24 rg 0.68
# 140 models [2] recycles 1 hard 1 soft 0 temp 1 loss 8.15 helix 1.19 pae 0.64 i_pae 0.68 con 3.80 i_con 4.11 plddt 0.33 ptm 0.79 i_ptm 0.24 rg 0.56
# Trajectory successful, final pLDDT: 0.84
# Starting trajectory took: 0 hours, 5 minutes, 22 seconds
#
# Fixing interface residues: B4,B5,B7,B8,B11,B12,B14,B15,B16,B17,B18,B19,B22
# Base AF2 filters not passed for 6ARU_l48_s723207_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s723207_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s723207_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s723207_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s723207_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s723207_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s723207_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s723207_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s723207_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s723207_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s723207_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s723207_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s723207_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s723207_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s723207_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s723207_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s723207_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s723207_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s723207_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s723207_mpnn1, skipping interface scoring
# No accepted MPNN designs found for this trajectory.
# Design and validation of trajectory 6ARU_l48_s723207 took: 0 hours, 1 minutes, 9 seconds
# Starting trajectory: 6ARU_l48_s647883
# Stage 1: Test Logits
# 1 models [3] recycles 1 hard 0 soft 0.02 temp 1 loss 11.56 helix 1.67 pae 0.76 i_pae 0.79 con 4.68 i_con 4.31 plddt 0.28 ptm 0.78 i_ptm 0.17 rg 8.62
# 2 models [4] recycles 1 hard 0 soft 0.04 temp 1 loss 11.33 helix 0.80 pae 0.74 i_pae 0.80 con 4.79 i_con 4.46 plddt 0.41 ptm 0.77 i_ptm 0.14 rg 6.14
# 3 models [1] recycles 1 hard 0 soft 0.05 temp 1 loss 9.21 helix 1.12 pae 0.67 i_pae 0.70 con 4.42 i_con 4.14 plddt 0.35 ptm 0.79 i_ptm 0.22 rg 1.81
# 4 models [0] recycles 1 hard 0 soft 0.07 temp 1 loss 8.64 helix 1.16 pae 0.67 i_pae 0.70 con 4.15 i_con 4.11 plddt 0.32 ptm 0.78 i_ptm 0.22 rg 0.96
# 5 models [1] recycles 1 hard 0 soft 0.09 temp 1 loss 8.41 helix 1.07 pae 0.65 i_pae 0.68 con 4.13 i_con 4.05 plddt 0.34 ptm 0.79 i_ptm 0.25 rg 0.41
# 6 models [3] recycles 1 hard 0 soft 0.11 temp 1 loss 8.04 helix 1.02 pae 0.60 i_pae 0.63 con 3.89 i_con 3.90 plddt 0.38 ptm 0.79 i_ptm 0.29 rg 0.50
# 7 models [3] recycles 1 hard 0 soft 0.13 temp 1 loss 8.07 helix 1.01 pae 0.61 i_pae 0.65 con 3.83 i_con 3.98 plddt 0.36 ptm 0.79 i_ptm 0.26 rg 0.50
# 8 models [2] recycles 1 hard 0 soft 0.14 temp 1 loss 8.27 helix 1.15 pae 0.65 i_pae 0.68 con 4.08 i_con 3.98 plddt 0.33 ptm 0.78 i_ptm 0.23 rg 0.40
# 9 models [2] recycles 1 hard 0 soft 0.16 temp 1 loss 7.93 helix 1.04 pae 0.63 i_pae 0.67 con 3.92 i_con 3.96 plddt 0.37 ptm 0.78 i_ptm 0.25 rg -0.19
# ...
# Initial trajectory pLDDT good, continuing: 0.75
# Stage 1: Additional Logits Optimisation
# 51 models [2] recycles 1 hard 0 soft 0.04 temp 1 loss 8.26 helix 1.06 pae 0.59 i_pae 0.62 con 4.12 i_con 3.75 plddt 0.44 ptm 0.79 i_ptm 0.30 rg 1.05
# 52 models [1] recycles 1 hard 0 soft 0.08 temp 1 loss 4.96 helix 1.03 pae 0.21 i_pae 0.23 con 2.13 i_con 2.40 plddt 0.82 ptm 0.90 i_ptm 0.79 rg 2.01
# 53 models [0] recycles 1 hard 0 soft 0.12 temp 1 loss 5.26 helix 1.08 pae 0.28 i_pae 0.31 con 2.12 i_con 2.75 plddt 0.76 ptm 0.86 i_ptm 0.65 rg 1.78
# 54 models [2] recycles 1 hard 0 soft 0.16 temp 1 loss 5.09 helix 0.98 pae 0.26 i_pae 0.29 con 2.00 i_con 2.65 plddt 0.81 ptm 0.86 i_ptm 0.68 rg 1.85
# 55 models [4] recycles 1 hard 0 soft 0.20 temp 1 loss 4.74 helix 1.03 pae 0.21 i_pae 0.23 con 1.96 i_con 2.35 plddt 0.84 ptm 0.89 i_ptm 0.79 rg 2.02
# 56 models [3] recycles 1 hard 0 soft 0.24 temp 1 loss 5.32 helix 1.00 pae 0.26 i_pae 0.28 con 2.26 i_con 2.70 plddt 0.76 ptm 0.88 i_ptm 0.69 rg 1.63
# 57 models [3] recycles 1 hard 0 soft 0.28 temp 1 loss 4.82 helix 1.02 pae 0.23 i_pae 0.25 con 1.99 i_con 2.44 plddt 0.82 ptm 0.89 i_ptm 0.76 rg 1.85
# 58 models [1] recycles 1 hard 0 soft 0.32 temp 1 loss 4.53 helix 1.11 pae 0.19 i_pae 0.21 con 1.92 i_con 2.22 plddt 0.85 ptm 0.90 i_ptm 0.82 rg 2.00
# 59 models [3] recycles 1 hard 0 soft 0.36 temp 1 loss 4.51 helix 1.02 pae 0.20 i_pae 0.21 con 1.90 i_con 2.17 plddt 0.85 ptm 0.90 i_ptm 0.82 rg 2.05
# 60 models [4] recycles 1 hard 0 soft 0.40 temp 1 loss 4.96 helix 1.10 pae 0.27 i_pae 0.30 con 1.93 i_con 2.68 plddt 0.81 ptm 0.87 i_ptm 0.67 rg 1.68
# 61 models [2] recycles 1 hard 0 soft 0.44 temp 1 loss 4.84 helix 1.00 pae 0.24 i_pae 0.27 con 1.94 i_con 2.52 plddt 0.83 ptm 0.88 i_ptm 0.70 rg 1.75
# 62 models [1] recycles 1 hard 0 soft 0.48 temp 1 loss 4.92 helix 1.07 pae 0.21 i_pae 0.22 con 2.17 i_con 2.26 plddt 0.82 ptm 0.91 i_ptm 0.82 rg 2.27
# 63 models [2] recycles 1 hard 0 soft 0.52 temp 1 loss 4.65 helix 1.09 pae 0.23 i_pae 0.25 con 1.91 i_con 2.42 plddt 0.84 ptm 0.88 i_ptm 0.75 rg 1.70
# 64 models [2] recycles 1 hard 0 soft 0.56 temp 1 loss 4.77 helix 1.06 pae 0.23 i_pae 0.25 con 1.98 i_con 2.38 plddt 0.83 ptm 0.88 i_ptm 0.77 rg 1.93
# 65 models [4] recycles 1 hard 0 soft 0.60 temp 1 loss 4.77 helix 1.07 pae 0.24 i_pae 0.27 con 1.92 i_con 2.48 plddt 0.81 ptm 0.88 i_ptm 0.74 rg 1.77
# 66 models [2] recycles 1 hard 0 soft 0.64 temp 1 loss 6.32 helix 1.05 pae 0.52 i_pae 0.61 con 2.23 i_con 3.76 plddt 0.64 ptm 0.78 i_ptm 0.25 rg 0.99
# 67 models [2] recycles 1 hard 0 soft 0.68 temp 1 loss 5.78 helix 1.08 pae 0.45 i_pae 0.52 con 2.00 i_con 3.44 plddt 0.70 ptm 0.80 i_ptm 0.34 rg 1.23
# 68 models [4] recycles 1 hard 0 soft 0.72 temp 1 loss 4.55 helix 1.10 pae 0.20 i_pae 0.22 con 1.88 i_con 2.36 plddt 0.85 ptm 0.89 i_ptm 0.79 rg 1.73
# 69 models [1] recycles 1 hard 0 soft 0.76 temp 1 loss 4.97 helix 0.98 pae 0.22 i_pae 0.23 con 2.13 i_con 2.39 plddt 0.81 ptm 0.90 i_ptm 0.78 rg 2.00
# 70 models [0] recycles 1 hard 0 soft 0.80 temp 1 loss 5.80 helix 1.04 pae 0.34 i_pae 0.37 con 2.43 i_con 3.01 plddt 0.68 ptm 0.85 i_ptm 0.57 rg 1.48
# 71 models [2] recycles 1 hard 0 soft 0.84 temp 1 loss 6.19 helix 1.05 pae 0.48 i_pae 0.56 con 2.30 i_con 3.56 plddt 0.64 ptm 0.79 i_ptm 0.31 rg 1.11
# 72 models [2] recycles 1 hard 0 soft 0.88 temp 1 loss 5.09 helix 1.00 pae 0.26 i_pae 0.29 con 2.08 i_con 2.62 plddt 0.80 ptm 0.87 i_ptm 0.70 rg 1.74
# 73 models [0] recycles 1 hard 0 soft 0.92 temp 1 loss 6.45 helix 1.06 pae 0.52 i_pae 0.60 con 2.39 i_con 3.74 plddt 0.58 ptm 0.78 i_ptm 0.27 rg 0.96
# 74 models [0] recycles 1 hard 0 soft 0.96 temp 1 loss 5.41 helix 0.96 pae 0.27 i_pae 0.29 con 2.20 i_con 2.76 plddt 0.76 ptm 0.87 i_ptm 0.67 rg 1.88
# 75 models [1] recycles 1 hard 0 soft 1 temp 1 loss 8.38 helix 0.87 pae 0.63 i_pae 0.67 con 3.99 i_con 3.99 plddt 0.40 ptm 0.78 i_ptm 0.24 rg 0.80
# Optimised logit trajectory pLDDT: 0.85
# Stage 2: Softmax Optimisation
# 76 models [4] recycles 1 hard 0 soft 1 temp 0.96 loss 5.36 helix 0.90 pae 0.26 i_pae 0.29 con 2.22 i_con 2.67 plddt 0.79 ptm 0.87 i_ptm 0.70 rg 1.88
# 77 models [1] recycles 1 hard 0 soft 1 temp 0.91 loss 5.28 helix 0.97 pae 0.26 i_pae 0.29 con 2.11 i_con 2.71 plddt 0.79 ptm 0.88 i_ptm 0.70 rg 1.93
# 78 models [0] recycles 1 hard 0 soft 1 temp 0.87 loss 5.74 helix 1.10 pae 0.42 i_pae 0.49 con 1.98 i_con 3.36 plddt 0.69 ptm 0.80 i_ptm 0.37 rg 1.53
# 79 models [4] recycles 1 hard 0 soft 1 temp 0.83 loss 5.45 helix 1.00 pae 0.32 i_pae 0.37 con 2.11 i_con 2.91 plddt 0.76 ptm 0.85 i_ptm 0.58 rg 1.73
# 80 models [1] recycles 1 hard 0 soft 1 temp 0.79 loss 5.27 helix 1.00 pae 0.28 i_pae 0.31 con 2.04 i_con 2.79 plddt 0.78 ptm 0.87 i_ptm 0.65 rg 1.84
# 81 models [2] recycles 1 hard 0 soft 1 temp 0.75 loss 6.21 helix 1.05 pae 0.50 i_pae 0.58 con 2.21 i_con 3.64 plddt 0.65 ptm 0.79 i_ptm 0.28 rg 1.17
# 82 models [0] recycles 1 hard 0 soft 1 temp 0.72 loss 5.36 helix 1.05 pae 0.33 i_pae 0.38 con 1.95 i_con 2.99 plddt 0.74 ptm 0.84 i_ptm 0.50 rg 1.70
# 83 models [2] recycles 1 hard 0 soft 1 temp 0.68 loss 5.35 helix 0.99 pae 0.32 i_pae 0.36 con 2.04 i_con 2.88 plddt 0.77 ptm 0.85 i_ptm 0.59 rg 1.73
# 84 models [4] recycles 1 hard 0 soft 1 temp 0.64 loss 5.79 helix 1.01 pae 0.41 i_pae 0.47 con 2.11 i_con 3.24 plddt 0.70 ptm 0.82 i_ptm 0.41 rg 1.56
# 85 models [2] recycles 1 hard 0 soft 1 temp 0.61 loss 6.31 helix 1.06 pae 0.55 i_pae 0.65 con 2.07 i_con 3.85 plddt 0.65 ptm 0.77 i_ptm 0.22 rg 1.16
# 86 models [3] recycles 1 hard 0 soft 1 temp 0.58 loss 6.02 helix 1.03 pae 0.50 i_pae 0.59 con 1.97 i_con 3.66 plddt 0.65 ptm 0.79 i_ptm 0.26 rg 1.25
# 87 models [3] recycles 1 hard 0 soft 1 temp 0.54 loss 5.88 helix 1.03 pae 0.47 i_pae 0.55 con 1.96 i_con 3.51 plddt 0.67 ptm 0.80 i_ptm 0.30 rg 1.34
# 88 models [4] recycles 1 hard 0 soft 1 temp 0.51 loss 5.39 helix 1.02 pae 0.32 i_pae 0.37 con 2.06 i_con 2.92 plddt 0.76 ptm 0.85 i_ptm 0.57 rg 1.67
# 89 models [2] recycles 1 hard 0 soft 1 temp 0.48 loss 5.90 helix 1.03 pae 0.43 i_pae 0.50 con 2.14 i_con 3.36 plddt 0.70 ptm 0.81 i_ptm 0.38 rg 1.43
# 90 models [0] recycles 1 hard 0 soft 1 temp 0.45 loss 5.00 helix 1.04 pae 0.26 i_pae 0.29 con 1.95 i_con 2.65 plddt 0.79 ptm 0.87 i_ptm 0.68 rg 1.79
# 91 models [2] recycles 1 hard 0 soft 1 temp 0.42 loss 5.59 helix 0.98 pae 0.37 i_pae 0.43 con 2.04 i_con 3.15 plddt 0.74 ptm 0.83 i_ptm 0.49 rg 1.51
# 92 models [1] recycles 1 hard 0 soft 1 temp 0.39 loss 5.03 helix 1.08 pae 0.26 i_pae 0.29 con 1.96 i_con 2.67 plddt 0.81 ptm 0.87 i_ptm 0.69 rg 1.89
# 93 models [0] recycles 1 hard 0 soft 1 temp 0.37 loss 5.61 helix 1.06 pae 0.40 i_pae 0.47 con 1.91 i_con 3.31 plddt 0.70 ptm 0.81 i_ptm 0.38 rg 1.47
# 94 models [3] recycles 1 hard 0 soft 1 temp 0.34 loss 6.06 helix 1.03 pae 0.49 i_pae 0.57 con 2.04 i_con 3.60 plddt 0.67 ptm 0.79 i_ptm 0.29 rg 1.37
# 95 models [2] recycles 1 hard 0 soft 1 temp 0.32 loss 5.74 helix 1.00 pae 0.42 i_pae 0.48 con 2.11 i_con 3.26 plddt 0.72 ptm 0.81 i_ptm 0.43 rg 1.36
# 96 models [3] recycles 1 hard 0 soft 1 temp 0.29 loss 5.74 helix 1.03 pae 0.41 i_pae 0.48 con 2.07 i_con 3.28 plddt 0.72 ptm 0.82 i_ptm 0.41 rg 1.45
# 97 models [1] recycles 1 hard 0 soft 1 temp 0.27 loss 5.26 helix 1.02 pae 0.26 i_pae 0.29 con 2.15 i_con 2.68 plddt 0.79 ptm 0.87 i_ptm 0.69 rg 1.90
# 98 models [1] recycles 1 hard 0 soft 1 temp 0.25 loss 4.89 helix 1.06 pae 0.21 i_pae 0.23 con 2.06 i_con 2.40 plddt 0.83 ptm 0.89 i_ptm 0.78 rg 2.03
# 99 models [2] recycles 1 hard 0 soft 1 temp 0.23 loss 5.57 helix 0.96 pae 0.31 i_pae 0.35 con 2.27 i_con 2.87 plddt 0.77 ptm 0.86 i_ptm 0.62 rg 1.74
# 100 models [4] recycles 1 hard 0 soft 1 temp 0.21 loss 6.81 helix 0.98 pae 0.51 i_pae 0.58 con 2.79 i_con 3.69 plddt 0.57 ptm 0.80 i_ptm 0.30 rg 0.96
# 101 models [0] recycles 1 hard 0 soft 1 temp 0.19 loss 5.45 helix 1.06 pae 0.28 i_pae 0.30 con 2.20 i_con 2.81 plddt 0.74 ptm 0.87 i_ptm 0.64 rg 1.88
# 102 models [2] recycles 1 hard 0 soft 1 temp 0.17 loss 5.34 helix 0.97 pae 0.30 i_pae 0.34 con 2.12 i_con 2.80 plddt 0.79 ptm 0.86 i_ptm 0.64 rg 1.73
# 103 models [4] recycles 1 hard 0 soft 1 temp 0.15 loss 5.03 helix 0.97 pae 0.23 i_pae 0.24 con 2.19 i_con 2.41 plddt 0.81 ptm 0.89 i_ptm 0.77 rg 1.90
# 104 models [1] recycles 1 hard 0 soft 1 temp 0.14 loss 4.91 helix 1.03 pae 0.23 i_pae 0.26 con 1.97 i_con 2.57 plddt 0.82 ptm 0.88 i_ptm 0.73 rg 1.77
# 105 models [0] recycles 1 hard 0 soft 1 temp 0.12 loss 5.16 helix 1.03 pae 0.26 i_pae 0.28 con 2.10 i_con 2.66 plddt 0.77 ptm 0.87 i_ptm 0.70 rg 1.83
# 106 models [0] recycles 1 hard 0 soft 1 temp 0.11 loss 5.28 helix 1.02 pae 0.30 i_pae 0.34 con 2.01 i_con 2.87 plddt 0.76 ptm 0.85 i_ptm 0.60 rg 1.70
# 107 models [1] recycles 1 hard 0 soft 1 temp 0.09 loss 4.89 helix 1.03 pae 0.21 i_pae 0.23 con 2.07 i_con 2.43 plddt 0.82 ptm 0.90 i_ptm 0.78 rg 1.88
# 108 models [1] recycles 1 hard 0 soft 1 temp 0.08 loss 6.41 helix 0.99 pae 0.42 i_pae 0.48 con 2.49 i_con 3.49 plddt 0.66 ptm 0.82 i_ptm 0.39 rg 1.48
# 109 models [4] recycles 1 hard 0 soft 1 temp 0.07 loss 5.40 helix 0.96 pae 0.32 i_pae 0.37 con 2.03 i_con 2.94 plddt 0.78 ptm 0.85 i_ptm 0.57 rg 1.67
# 110 models [1] recycles 1 hard 0 soft 1 temp 0.06 loss 5.15 helix 1.07 pae 0.26 i_pae 0.30 con 2.02 i_con 2.70 plddt 0.80 ptm 0.87 i_ptm 0.67 rg 1.92
# 111 models [1] recycles 1 hard 0 soft 1 temp 0.05 loss 5.10 helix 1.06 pae 0.23 i_pae 0.25 con 2.08 i_con 2.59 plddt 0.81 ptm 0.89 i_ptm 0.73 rg 1.96
# 112 models [2] recycles 1 hard 0 soft 1 temp 0.04 loss 5.55 helix 1.04 pae 0.32 i_pae 0.37 con 2.21 i_con 2.94 plddt 0.77 ptm 0.85 i_ptm 0.58 rg 1.69
# 113 models [2] recycles 1 hard 0 soft 1 temp 0.03 loss 5.81 helix 1.03 pae 0.38 i_pae 0.44 con 2.22 i_con 3.16 plddt 0.75 ptm 0.83 i_ptm 0.47 rg 1.62
# 114 models [0] recycles 1 hard 0 soft 1 temp 0.03 loss 5.04 helix 1.06 pae 0.24 i_pae 0.27 con 2.03 i_con 2.61 plddt 0.80 ptm 0.87 i_ptm 0.70 rg 1.87
# 115 models [2] recycles 1 hard 0 soft 1 temp 0.02 loss 6.30 helix 1.01 pae 0.51 i_pae 0.60 con 2.12 i_con 3.78 plddt 0.68 ptm 0.79 i_ptm 0.26 rg 1.26
# 116 models [4] recycles 1 hard 0 soft 1 temp 0.02 loss 5.01 helix 1.03 pae 0.25 i_pae 0.28 con 2.01 i_con 2.59 plddt 0.81 ptm 0.88 i_ptm 0.71 rg 1.84
# 117 models [1] recycles 1 hard 0 soft 1 temp 0.01 loss 6.44 helix 1.09 pae 0.54 i_pae 0.64 con 2.06 i_con 3.92 plddt 0.66 ptm 0.78 i_ptm 0.23 rg 1.46
# 118 models [4] recycles 1 hard 0 soft 1 temp 0.01 loss 5.28 helix 0.99 pae 0.29 i_pae 0.33 con 2.08 i_con 2.78 plddt 0.79 ptm 0.86 i_ptm 0.63 rg 1.73
# 119 models [2] recycles 1 hard 0 soft 1 temp 0.01 loss 5.84 helix 1.01 pae 0.42 i_pae 0.49 con 2.10 i_con 3.32 plddt 0.73 ptm 0.81 i_ptm 0.41 rg 1.51
# 120 models [4] recycles 1 hard 0 soft 1 temp 0.01 loss 5.48 helix 1.03 pae 0.34 i_pae 0.38 con 2.12 i_con 2.94 plddt 0.77 ptm 0.85 i_ptm 0.56 rg 1.70
# Softmax trajectory pLDDT good, continuing: 0.83
# Stage 3: One-hot Optimisation
# 121 models [0] recycles 1 hard 1 soft 1 temp 0.01 loss 5.13 helix 1.05 pae 0.28 i_pae 0.31 con 1.95 i_con 2.78 plddt 0.75 ptm 0.87 i_ptm 0.64 rg 1.80
# 122 models [2] recycles 1 hard 1 soft 1 temp 0.01 loss 5.75 helix 1.03 pae 0.40 i_pae 0.47 con 2.06 i_con 3.24 plddt 0.70 ptm 0.82 i_ptm 0.44 rg 1.64
# 123 models [0] recycles 1 hard 1 soft 1 temp 0.01 loss 5.13 helix 1.05 pae 0.28 i_pae 0.31 con 1.95 i_con 2.78 plddt 0.75 ptm 0.87 i_ptm 0.64 rg 1.80
# 124 models [0] recycles 1 hard 1 soft 1 temp 0.01 loss 5.13 helix 1.05 pae 0.28 i_pae 0.31 con 1.95 i_con 2.78 plddt 0.75 ptm 0.87 i_ptm 0.64 rg 1.80
# 125 models [1] recycles 1 hard 1 soft 1 temp 0.01 loss 4.87 helix 1.06 pae 0.23 i_pae 0.26 con 1.92 i_con 2.55 plddt 0.79 ptm 0.89 i_ptm 0.73 rg 1.88
# One-hot trajectory pLDDT good, continuing: 0.79
# Stage 4: PSSM Semigreedy Optimisation
# Running semigreedy optimization...
# 126 models [1] recycles 1 hard 1 soft 0 temp 1 loss 5.01 helix 1.08 pae 0.25 i_pae 0.28 con 1.95 i_con 2.65 plddt 0.78 ptm 0.88 i_ptm 0.70 rg 1.91
# 127 models [0] recycles 1 hard 1 soft 0 temp 1 loss 4.97 helix 1.07 pae 0.24 i_pae 0.26 con 2.00 i_con 2.57 plddt 0.78 ptm 0.88 i_ptm 0.72 rg 1.87
# 128 models [0] recycles 1 hard 1 soft 0 temp 1 loss 5.07 helix 1.06 pae 0.25 i_pae 0.28 con 2.03 i_con 2.64 plddt 0.76 ptm 0.88 i_ptm 0.69 rg 1.84
# 129 models [1] recycles 1 hard 1 soft 0 temp 1 loss 4.75 helix 1.10 pae 0.21 i_pae 0.23 con 2.05 i_con 2.35 plddt 0.79 ptm 0.90 i_ptm 0.79 rg 1.79
# 130 models [1] recycles 1 hard 1 soft 0 temp 1 loss 5.02 helix 0.95 pae 0.20 i_pae 0.21 con 2.29 i_con 2.30 plddt 0.79 ptm 0.91 i_ptm 0.82 rg 1.96
# 131 models [0] recycles 1 hard 1 soft 0 temp 1 loss 5.71 helix 0.98 pae 0.25 i_pae 0.26 con 2.53 i_con 2.66 plddt 0.73 ptm 0.89 i_ptm 0.74 rg 2.14
# 132 models [2] recycles 1 hard 1 soft 0 temp 1 loss 7.42 helix 0.92 pae 0.54 i_pae 0.59 con 3.27 i_con 3.77 plddt 0.48 ptm 0.80 i_ptm 0.30 rg 0.98
# 133 models [3] recycles 1 hard 1 soft 0 temp 1 loss 7.51 helix 0.92 pae 0.54 i_pae 0.60 con 3.22 i_con 3.84 plddt 0.46 ptm 0.80 i_ptm 0.29 rg 1.21
# 134 models [0] recycles 1 hard 1 soft 0 temp 1 loss 6.62 helix 0.92 pae 0.47 i_pae 0.53 con 2.68 i_con 3.59 plddt 0.53 ptm 0.81 i_ptm 0.35 rg 1.03
# 135 models [1] recycles 1 hard 1 soft 0 temp 1 loss 7.40 helix 0.91 pae 0.49 i_pae 0.53 con 3.41 i_con 3.62 plddt 0.50 ptm 0.82 i_ptm 0.37 rg 1.05
# 136 models [2] recycles 1 hard 1 soft 0 temp 1 loss 7.99 helix 0.89 pae 0.59 i_pae 0.64 con 3.60 i_con 3.94 plddt 0.41 ptm 0.79 i_ptm 0.25 rg 1.09
# 137 models [3] recycles 1 hard 1 soft 0 temp 1 loss 7.87 helix 0.92 pae 0.56 i_pae 0.60 con 3.67 i_con 3.85 plddt 0.41 ptm 0.80 i_ptm 0.30 rg 0.82
# 138 models [2] recycles 1 hard 1 soft 0 temp 1 loss 7.84 helix 0.90 pae 0.57 i_pae 0.62 con 3.60 i_con 3.90 plddt 0.44 ptm 0.79 i_ptm 0.26 rg 0.74
# 139 models [4] recycles 1 hard 1 soft 0 temp 1 loss 7.73 helix 0.89 pae 0.54 i_pae 0.59 con 3.54 i_con 3.79 plddt 0.45 ptm 0.80 i_ptm 0.30 rg 0.99
# 140 models [1] recycles 1 hard 1 soft 0 temp 1 loss 7.06 helix 0.88 pae 0.41 i_pae 0.45 con 3.11 i_con 3.43 plddt 0.57 ptm 0.83 i_ptm 0.45 rg 1.68
# Trajectory successful, final pLDDT: 0.79
# Starting trajectory took: 0 hours, 5 minutes, 40 seconds
#
# Fixing interface residues: B8,B11,B14,B15,B18,B22,B29,B30,B31,B32,B33,B34,B37,B41,B44,B45,B48
# Base AF2 filters not passed for 6ARU_l48_s782540_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s782540_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s782540_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s782540_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s782540_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s782540_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s782540_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s782540_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s782540_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s782540_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s782540_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s782540_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s782540_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s782540_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s782540_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s782540_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s782540_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s782540_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s782540_mpnn1, skipping interface scoring
# Base AF2 filters not passed for 6ARU_l48_s782540_mpnn1, skipping interface scoring
# No accepted MPNN designs found for this trajectory.
# Design and validation of trajectory 6ARU_l48_s782540 took: 0 hours, 1 minutes, 24 seconds
# Starting trajectory: 6ARU_l48_s938807
# Stage 1: Test Logits
# 1 models [1] recycles 1 hard 0 soft 0.02 temp 1 loss 10.86 helix 1.58 pae 0.72 i_pae 0.74 con 4.60 i_con 4.37 plddt 0.31 ptm 0.79 i_ptm 0.20 rg 6.33

# %%
#@title Consolidate & Rank Designs
#@markdown ---
accepted_binders = [f for f in os.listdir(design_paths["Accepted"]) if f.endswith('.pdb')]

for f in os.listdir(design_paths["Accepted/Ranked"]):
    os.remove(os.path.join(design_paths["Accepted/Ranked"], f))

# load dataframe of designed binders
design_df = pd.read_csv(mpnn_csv)
design_df = design_df.sort_values('Average_i_pTM', ascending=False)

# create final csv dataframe to copy matched rows, initialize with the column labels
final_df = pd.DataFrame(columns=final_labels)

# check the ranking of the designs and copy them with new ranked IDs to the folder
rank = 1
for _, row in design_df.iterrows():
    for binder in accepted_binders:
        target_settings["binder_name"], model = binder.rsplit('_model', 1)
        if target_settings["binder_name"] == row['Design']:
            # rank and copy into ranked folder
            row_data = {'Rank': rank, **{label: row[label] for label in design_labels}}
            final_df = pd.concat([final_df, pd.DataFrame([row_data])], ignore_index=True)
            old_path = os.path.join(design_paths["Accepted"], binder)
            new_path = os.path.join(design_paths["Accepted/Ranked"], f"{rank}_{target_settings['binder_name']}_model{model.rsplit('.', 1)[0]}.pdb")
            shutil.copyfile(old_path, new_path)

            rank += 1
            break

# save the final_df to final_csv
final_df.to_csv(final_csv, index=False)

print("Designs ranked and final_designs_stats.csv generated")

# %%
#@title Top 20 Designs
df = pd.read_csv(os.path.join(design_path, 'final_design_stats.csv'))
df.head(20)

# %%
#@title Top Design Display
import py3Dmol
import glob
from IPython.display import HTML

#### pymol top design
top_design_dir = os.path.join(design_path, 'Accepted', 'Ranked')
top_design_pdb = glob.glob(os.path.join(top_design_dir, '1_*.pdb'))[0]

# Visualise in PyMOL
view = py3Dmol.view()
view.addModel(open(top_design_pdb, 'r').read(),'pdb')
view.setBackgroundColor('white')
view.setStyle({'chain':'A'}, {'cartoon': {'color':'#3c5b6f'}})
view.setStyle({'chain':'B'}, {'cartoon': {'color':'#B76E79'}})
view.zoomTo()
view.show()

# %%
#@title Display animation
import glob
from IPython.display import HTML

#### pymol top design
top_design_dir = os.path.join(design_path, 'Accepted', 'Ranked')
top_design_pdb = glob.glob(os.path.join(top_design_dir, '1_*.pdb'))[0]

top_design_name = os.path.basename(top_design_pdb).split('1_', 1)[1].split('_mpnn')[0]
top_design_animation = os.path.join(design_path, 'Accepted', 'Animation', f"{top_design_name}.html")

# Show animation
HTML(top_design_animation)
